# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import urllib2
from pylab import rcParams
rcParams['figure.figsize'] = 15, 10

# %%
import sys
import platform
import matplotlib
print("Operating System " + platform.system() + " " + platform.release())
print("Python Version " + str(sys.version))
print("Pandas Version " + str(pd.__version__))
print("Numpy Version " + str(np.__version__))
print("Matplotlib Version " + str(matplotlib.__version__))
# Out:
# Operating System Windows 7
# Python Version 2.7.8 (default, Jun 30 2014, 16:03:49) [MSC v.1500 32 bit (Intel)]
# Pandas Version 0.17.1
# Numpy Version 1.10.4
# Matplotlib Version 1.5.1

# %%
paramcodeURL = "http://nwis.waterdata.usgs.gov/nwis/pmcodes?radio_pm_search=param_group&pm_group=All+--+include+all+parameter+groups&pm_search=&casrn_search=&srsname_search=&format=rdb&show=parameter_group_nm&show=parameter_nm&show=casrn&show=srsname&show=parameter_units"

# %%
NWISParam = pd.read_table(paramcodeURL,comment='#')

# %%
NWISParam = NWISParam.loc[1:]

# %%
NWISParam
# Out:
#       parameter_cd parameter_group_nm  \
# 1            00001        Information
# 2            00002        Information
# 3            00003        Information
# 4            00005        Information
# 5            00008        Information
# 6            00009        Information
# 7            00022        Information
# 8            00023        Information
# 9            00024        Information
# 10           00028        Information
# 11           00029        Information
# 12           00041        Information
# 13           00042        Information
# 14           00054        Information
# 15           00063        Information
# 16           00098        Information
# 17           00100        Information
# 18           00115        Information
# 19           00132        Information
# 20           00134        Information
# 21           00135        Information
# 22           00206        Information
# 23           00207        Information
# 24           04117        Information
# 25           04118        Information
# 26           04119        Information
# 27           04120        Information
# 28           04121        Information
# 29           30215        Information
# 30           30216        Information
# ...            ...                ...
# 16391        80230           Sediment
# 16392        80231           Sediment
# 16393        80232           Sediment
# 16394        80233           Sediment
# 16395        80234           Sediment
# 16396        80235           Sediment
# 16397        80236           Sediment
# 16398        80237           Sediment
# 16399        80238           Sediment
# 16400        80239           Sediment
# 16401        80240           Sediment
# 16402        80282           Sediment
# 16403        80283           Sediment
# 16404        80284           Sediment
# 16405        80285           Sediment
# 16406        80286           Sediment
# 16407        80287           Sediment
# 16408        80288           Sediment
# 16409        80289           Sediment
# 16410        80290           Sediment
# 16411        80291           Sediment
# 16412        80292           Sediment
# 16413        80293           Sediment
# 16414        80294           Sediment
# 16415        80295           Sediment
# 16416        80296           Sediment
# 16417        80297           Sediment
# 16418        80298           Sediment
# 16419        91145           Sediment
# 16420        99409           Sediment
#
#                                             parameter_nm casrn  \
# 1      Location in cross section, distance from right...   NaN
# 2      Location in cross section, distance from right...   NaN
# 3                                   Sampling depth, feet   NaN
# 4      Location in cross section, fraction of total d...   NaN
# 5                               Sample accounting number   NaN
# 6      Location in cross section, distance from left ...   NaN
# 7             Duration of exposure, sample or test, days   NaN
# 8                                  Sample weight, pounds   NaN
# 9                                  Sample length, inches   NaN
# 10                         Agency analyzing sample, code   NaN
# 11                                        Project number   NaN
# 12       Weather, World Meteorological Organization code   NaN
# 13                   Altitude, feet above mean sea level   NaN
# 14                          Reservoir storage, acre feet   NaN
# 15                      Number of sampling points, count   NaN
# 16                                Sampling depth, meters   NaN
# 17                                 Time of travel, hours   NaN
# 18                                Sample treatment, code   NaN
# 19             Dry days before precipitation event, days   NaN
# 20                             Storm event serial number   NaN
# 21                          Elapsed time of storm, hours   NaN
# 22         Collector area, wet deposition, square meters   NaN
# 23         Collector area, dry deposition, square meters   NaN
# 24     Tether line used for collecting sample (yes=1)...   NaN
# 25     Composited samples in cross-sectional bedload ...   NaN
# 26                 Verticals in composite sample, number   NaN
# 27         Rest time on bed for bed load sample, seconds   NaN
# 28                    Horizontal width of vertical, feet   NaN
# 29               Signal, sediment, Markland meter, count   NaN
# 30                    Voltage, hazard trip switch, volts   NaN
# ...                                                  ...   ...
# 16391  Bedload sediment, sieve diameter, percent smal...   NaN
# 16392  Bedload sediment, sieve diameter, percent smal...   NaN
# 16393  Bedload sediment, sieve diameter, percent smal...   NaN
# 16394  Bedload sediment, sieve diameter, percent smal...   NaN
# 16395  Bedload sediment, sieve diameter, percent smal...   NaN
# 16396  Bedload sediment, sieve diameter, percent smal...   NaN
# 16397  Bedload sediment, sieve diameter, percent smal...   NaN
# 16398  Bedload sediment, sieve diameter, percent smal...   NaN
# 16399  Bedload sediment, sieve diameter, percent smal...   NaN
# 16400  Bed sediment, sieve diameter, percent smaller ...   NaN
# 16401  Bed sediment, dry sieved, sieve diameter, perc...   NaN
# 16402  Bed sediment, fall diameter (deionized water),...   NaN
# 16403  Bed sediment, fall diameter (deionized water),...   NaN
# 16404  Bed sediment, fall diameter (deionized water),...   NaN
# 16405  Bed sediment, fall diameter (deionized water),...   NaN
# 16406  Bed sediment, fall diameter (deionized water),...   NaN
# 16407  Total sediment, fall diameter (deionized water...   NaN
# 16408  Total sediment, fall diameter (deionized water...   NaN
# 16409  Total sediment, fall diameter (deionized water...   NaN
# 16410  Total sediment, fall diameter (native water), ...   NaN
# 16411  Total sediment, fall diameter (native water), ...   NaN
# 16412  Total sediment, fall diameter (native water), ...   NaN
# 16413  Bed sediment, fall diameter (deionized water),...   NaN
# 16414  Bed sediment, fall diameter (deionized water),...   NaN
# 16415  Suspended sediment load, water, unfiltered, es...   NaN
# 16416  Suspended sediment load, water, unfiltered, es...   NaN
# 16417  Suspended sediment load, water, unfiltered, co...   NaN
# 16418  Suspended sediment load, water, unfiltered, re...   NaN
# 16419  Bedload sediment, total sample mass, dry weigh...   NaN
# 16420  Suspended sediment concentration, water, unfil...   NaN
#
#                                   srsname parameter_units
# 1                                     NaN              ft
# 2                                     NaN               %
# 3                                     NaN              ft
# 4                                     NaN               %
# 5                                     NaN              nu
# 6                                     NaN              ft
# 7                                     NaN            days
# 8                                     NaN              lb
# 9                                     NaN              in
# 10                                    NaN            code
# 11                                    NaN              nu
# 12                                    NaN        WMO code
# 13                               Altitude      ft abv MSL
# 14                      Reservoir storage           ac-ft
# 15                                    NaN           count
# 16                                    NaN               m
# 17                                    NaN           hours
# 18                                    NaN            code
# 19     Dry period preceding precipitation            days
# 20                                    NaN              nu
# 21                                    NaN           hours
# 22                                    NaN              m2
# 23                                    NaN              m2
# 24                                    NaN            code
# 25                                    NaN              nu
# 26                                    NaN              nu
# 27                                    NaN         seconds
# 28                                    NaN              ft
# 29                                    NaN           count
# 30                                    NaN           volts
# ...                                   ...             ...
# 16391                            Sediment               %
# 16392                            Sediment               %
# 16393                            Sediment               %
# 16394                            Sediment               %
# 16395                            Sediment               %
# 16396                            Sediment               %
# 16397                            Sediment               %
# 16398                            Sediment               %
# 16399                            Sediment               %
# 16400                            Sediment               %
# 16401                            Sediment               %
# 16402                            Sediment               %
# 16403                            Sediment               %
# 16404                            Sediment               %
# 16405                            Sediment               %
# 16406                            Sediment               %
# 16407                            Sediment               %
# 16408                            Sediment               %
# 16409                            Sediment               %
# 16410                            Sediment               %
# 16411                            Sediment               %
# 16412                            Sediment               %
# 16413                            Sediment               %
# 16414                            Sediment               %
# 16415                                 NaN            lb/s
# 16416                                 NaN          tons/s
# 16417                                 NaN        tons/day
# 16418                                 NaN        tons/day
# 16419                                 NaN               g
# 16420                            Sediment            mg/l
#
# [16420 rows x 6 columns]

# %%
def parMedia(x):
    '''
    parses sample media based on parameter description
    
    http://waterqualitydata.us/portal_userguide/#WQPUserGuide-Table2
    '''
    if ', water, ' in x:
        media = 'water'
    elif ' soil, ' in x:
        media = 'soil'
    elif ', solids' in x:
        media = 'soil'
    elif ', rock, ' in x:
        media = 'rock'
    elif ', biota, ' in x:
        media = 'biota'
    elif 'atmospheric deposition, ' in x:
        media = 'air'
    elif ', bed sediment' in x:
        media = 'bed sediment'
    elif ', suspended sediment' in x:
        media = 'suspended sediment'
    elif ', air, ' in x:
        media = 'air'
    else:
        media = ''
    return media
        
def parSampFrac(x):
    '''
    parses sample fraction based on parameter description
    '''
    if ', dissolved,' in x:
        sampfrac = 'dissolved' 
    elif ', filtered' in x:
        sampfrac = 'filtered'
    elif ', unfiltered' in x:
        sampfrac = 'unfiltered'
    else:
        sampfrac = ''
    return sampfrac

def fieldCol(x):
    if ', field, ' in x:
        fieldCol = 'field'
    elif ', lab, ' in x:
        fieldCol = 'lab'
    else:
        fieldCol = ''
    return fieldCol

def getLast(x):
    return str(x).split(", ")[-1]

def getAsUnits(x):
    g = x.split("as ")
    if len(g) > 1:
        return g[-1]

# %%
NWISParam['media'] = NWISParam['parameter_nm'].apply(lambda x: parMedia(x), 1) # defines sample media based on parameter description 
NWISParam['sampfrac'] = NWISParam['parameter_nm'].apply(lambda x: parSampFrac(x), 1) # defines sample fraction based on parameter description
NWISParam['fieldCol'] = NWISParam['parameter_nm'].apply(lambda x: fieldCol(x),1)
NWISParam['units'] = NWISParam['parameter_nm'].apply(lambda x: getLast(x), 1)
NWISParam['asUnits'] = NWISParam['units'].apply(lambda x: getAsUnits(x), 1)
NWISParam['lwrSRS'] = NWISParam['srsname'].apply(lambda x: str(x).lower(), 1)

# %%
NWISParamWater = NWISParam[(NWISParam['media']=='water')|(NWISParam['media']=='')]

# %%
NWISParamWater[NWISParamWater['lwrSRS']=='temperature']['parameter_group_nm'].values[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-121-720eea93cc72> in <module>()
# ----> 1 NWISParamWater[NWISParamWater['lwrSRS']=='temperature']['parameter_group_nm'].values[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
NWISParamWater[NWISParamWater['parameter_cd']=='00931']
# Out:
#      parameter_cd         parameter_group_nm  \
# 1965        00931  Inorganics, Major, Metals
#
#                                       parameter_nm casrn  \
# 1965  Sodium adsorption ratio (SAR), water, number   NaN
#
#                       srsname parameter_units  media sampfrac   units asUnits  \
# 1965  Sodium adsorption ratio            None  water           number    None
#
#      fieldCol
# 1965

# %%
DBParamFile = "E:/GitHub/ParamGroup/DB_Params.csv"

# %%
DBParam = pd.read_csv(DBParamFile)

# %%
DBParam.dropna(subset=['Param'],inplace=True)

# %%
DBParam.drop_duplicates(subset=['Param'],inplace=True)

# %%
def getCAS(x, NWISParamWater):
    try:
        return NWISParamWater[NWISParamWater['lwrSRS']==str(x).lower()]['casrn'].values[0]
    except:
        try:
            return NWISParamWater[NWISParamWater['lwrSRS']==str(x).lower().split(' (')[0]]['casrn'].values[0]
        except:
            try:
                return NWISParamWater[NWISParamWater['lwrSRS']==str(x).lower().split(', ')[0]]['casrn'].values[0]
            except:
                return np.nan
def getPG(x, NWISParamWater):
    try:
        return NWISParamWater[NWISParamWater['lwrSRS']==str(x).lower()]['parameter_group_nm'].values[0]
    except:
        try:
            return NWISParamWater[NWISParamWater['lwrSRS']==str(x).lower().split(' (')[0]]['parameter_group_nm'].values[0]
        except:
            try:
                return NWISParamWater[NWISParamWater['lwrSRS']==str(x).lower().split(', ')[0]]['parameter_group_nm'].values[0]
            except:
                return np.nan

# %%
DBParam['CAS_Reg'] = DBParam['Param'].apply(lambda x: getCAS(x, NWISParamWater),1)
DBParam['ParamGroup'] = DBParam['Param'].apply(lambda x: getPG(x, NWISParamWater),1)

# %%
DBParam.to_clipboard()
