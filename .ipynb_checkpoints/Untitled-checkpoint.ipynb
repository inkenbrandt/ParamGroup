# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from pylab import rcParams
rcParams['figure.figsize'] = 15, 10

# %%
import sys
import platform
import matplotlib
print("Operating System " + platform.system() + " " + platform.release())
print("Python Version " + str(sys.version))
print("Pandas Version " + str(pd.__version__))
print("Numpy Version " + str(np.__version__))
print("Matplotlib Version " + str(matplotlib.__version__))
# Out:
# Operating System Windows 7
# Python Version 2.7.8 (default, Jun 30 2014, 16:03:49) [MSC v.1500 32 bit (Intel)]
# Pandas Version 0.17.0
# Numpy Version 1.9.3
# Matplotlib Version 1.4.3

# %%
inorganics_major_metals = ['calcium', 'dissolved calcium', 'dissolved magnesium', 'dissolved potassium', 'dissolved sodium', 
                           'magnesium', 'potassium', 'sodium', 'sodium adsorption ratio', 
                           'sodium adsorption ratio [(na)/(sq root of 1/2 ca + mg)]', 'sodium plus potassium', 
                           'sodium, percent total cations', 'total calcium', 'total magnesium', 'total potassium', 
                           'total sodium', 'percent sodium', 'hypochlorite ion']  # noqa
inorganics_major_nonmetals = ['acidity as caco3', 'alkalinity', 'alkalinity, bicarbonate as caco3', 
                              'alkalinity, carbonate as caco3', 'alkalinity, hydroxide as caco3', 
                              'alkalinity, phenolphthalein (total hydroxide+1/2 carbonate)', 'alkalinity, total', 
                              'alkalinity, total as caco3', 'bicarbonate', 'bicarbonate as caco3', 'bicarbonate as hco3', 
                              'bromide', 'carbon dioxide', 'carbonate', 'carbonate (co3)', 'carbonate as caco3', 
                              'carbonate as co3', 'chloride', 'chlorine', 'dissolved oxygen (do)', 'dissolved oxygen (field)', 
                              'dissolved oxygen saturation', 'fluoride', 'fluorine', 'gran acid neutralizing capacity',
                                      'hydrogen', 'hydrogen ion', 'hydroxide', 'inorganic carbon', 'oxygen', 'silica', 
                              'silicon', 'sulfate', 'sulfide', 'sulfur', 'total alkalinity as caco3', 'total carbon', 
                              'silica d/sio2', 't. alk/caco3', 'alkalinity as cac03', 'silica, dis. si02', 'carbon, total', 
                              'chlorine dioxide', 'chlorite', 'residual chlorine', 'hydroxide as calcium carbonate', 
                              'hydrogen sulfide', 'alkalinity, caco3 stability', 'acidity, total (caco3)', 'acidity, m.o. (caco3)', 'alkalinity, bicarbonate', 'alkalinity, carbonate', 'alkalinity, phenolphthalein', 'total chlorine', 'combined chlorine', 'perchlorate', 'free residual chlorine']  # noqa
inorganics_minor_nonmetals = ['antimony', 'argon', 'arsenate (aso43-)', 'arsenic', 'arsenite', 'boron', 'bromine', 'cyanide', 
                              'cyanides amenable to chlorination (hcn & cn)', 'dissolved arsenic', 'dissolved boron', 
                              'dissolved selenium', 'germanium', 'helium', 'iodide', 'krypton', 'neon', 'perchlorate', 
                              'selenium', 'sulfur hexafluoride', 'tellurium', 'total arsenic', 'total boron', 'total selenium', 
                              'xenon', 'chlorate', 'antimony, total', 'boron, total', 'asbestos']
inorganics_minor_metals = ['aluminum', 'barium', 'beryllium', 'bismuth', 'cadmium', 'cerium', 'cesium', 'chromium', 
                           'chromium(iii)', 'chromium(vi)', 'cobalt', 'copper', 'dissolved aluminum', 'dissolved barium', 
                           'dissolved cadmium', 'dissolved chromium', 'dissolved copper', 'dissolved iron', 'dissolved lead', 
                           'dissolved manganese', 'dissolved mercury', 'dissolved molybdenum', 'dissolved nickel', 
                           'dissolved zinc', 'dysprosium', 'erbium', 'europium', 'gadolinium', 'gallium', 'holmium', 
                           'iron', 'iron, ion (fe2+)', 'lanthanum', 'lead', 'lithium', 'lutetium', 'manganese', 'mercury', 
                           'molybdenum', 'neodymium', 'nickel', 'niobium', 'praseodymium', 'rhenium', 'rubidium', 'samarium', 
                           'scandium', 'silver', 'strontium', 'terbium', 'thallium', 'thulium', 'tin', 'titanium', 
                           'total aluminum', 'total barium', 'total cadmium', 'total chromium', 'total copper', 'total iron', 
                           'total iron-d max, dmr', 'total lead', 'total manganese', 'total mercury', 'total molybdenum', 
                           'total nickel', 'total zinc', 'tungsten', 'vanadium', 'ytterbium', 'yttrium', 'zinc', 'zirconium',
                           'iron, dissolved', 'chromium, hex, as cr', 'copper, free', 'iron, suspended', 'manganese, suspended', 
                           'beryllium, total', 'bismuth, total', 'chromium, hex', 'cobalt, total', 'lithium, total', 
                           'molybdenum, total', 'thallium, total', 'tin, total', 'titanium, total', 'vanadium, total', 
                           'lead summary', 'copper summary', 'manganese, dissolved']   # noqa
nutrient = ['ammonia', 'ammonia and ammonium', 'ammonia as n', 'ammonia as nh3', 'ammonia-nitrogen', 
            'ammonia-nitrogen as n', 'ammonium', 'ammonium as n', 'dissolved nitrate: no3', 
            'inorganic nitrogen (nitrate and nitrite)', 'inorganic nitrogen (nitrate and nitrite) as n', 
            'kjeldahl nitrogen', 'nitrate', 'nitrate as n', 'nitrate-nitrogen', 'nitrite', 'nitrite as n', 
            'nitrogen', 'orthophosphate', 'nitrogen, ammonium/ammonia ratio', 'dissolved nitrite: no2', 
            'nitrogen, mixed forms (nh3), (nh4), organic, (no2) and (no3)',
            'no2+no3 as n', 'organic nitrogen', 'ortho. phosphate', 'orthophosphate as p', 'phosphate', 
            'phosphate-phosphorus', 'phosphate-phosphorus as p', 'phosphate-phosphorus as po4', 'phosphorus', 
            'total phosphorus', 'nitrate + nitrite as n', 'phosphate, tot. dig. (as p)', 't.k.n.', 'phosphorus 0 as p', 
            'nitrogen-ammonia as (n)', 'nitrate-nitrite', 'phosphate, total', 'total kjeldahl nitrogen (in water mg/l)', 
            'phosphorus, soluble', 'phosphate, reactive', 'phosphorus, total']

# %%
import xmltodict
infile = "C:/Users/PAULINKENBRANDT/Downloads/ResultSampleFraction/Results.xml"
#infile = "C:/Users/PAULINKENBRANDT/Downloads/ResultMeasureValuePickList/Results.xml"

with open(infile) as fd:
    # parse xml to a dictionary, encode for degree signs
    obj = xmltodict.parse(fd.read(), encoding="UTF-8", xml_attribs=True)

rows = int(obj["WQXDomainValueList"]["WQXElement"]['WQXElementName']['@rowCount'])
cols = len(obj["WQXDomainValueList"]["WQXElement"]["WQXElementRow"][0]['WQXElementRowColumn'])

head = []
f = {}
for j in range(cols):
    head.append(obj["WQXDomainValueList"]["WQXElement"]["WQXElementRow"][0]['WQXElementRowColumn'][j]['@colname'])
    rowlist= []
    for i in range(rows):
        rowlist.append(obj["WQXDomainValueList"]["WQXElement"]["WQXElementRow"][i]['WQXElementRowColumn'][j]['@value'])
        f[head[j]] = rowlist

# %%
SDWISlist = pd.read_csv("E:/GitHub/ParamGroup/PARAM_MATCH.txt")
NWISlist = pd.read_table("E:/GitHub/ParamGroup/parameter_cd_query.txt",skiprows=[0,1,2,3,4,5,6,8])

# %%
SDWISlist

def parMedia(x):
    if ', water, ' in x:
        media = 'water'
    elif ' soil, ' in x:
        media = 'soil'
    elif ', solids' in x:
        media = 'soil'
    elif ', rock, ' in x:
        media = 'rock'
    elif ', biota, ' in x:
        media = 'biota'
    elif ', air, ' in x:
        media = 'air'
    else:
        media = ''
    return media
        
def parSampFrac(x):
    if ', dissolved,' in x:
        sampfrac = 'Dissolved' 
    elif ', filtered' in x:
        sampfrac = 'Filtered'
    elif ', unfiltered' in x:
        sampfrac = 'Unfiltered'
    else:
        sampfrac = ''
    return sampfrac
        
SDWISlist['media'] = SDWISlist["parameter_nm"].apply(lambda x: parMedia(x), 1)
SDWISlist['sampfrac'] = SDWISlist["parameter_nm"].apply(lambda x: parSampFrac(x), 1)

# %%
SDWISlist = SDWISlist[SDWISlist['media']=='water']

# %%
def ListMake(df,parName,groupName):
    df["lowerNAME"] = df[parName].apply(lambda x: str(x).lower().strip(), 1)
    groups = list(df[groupName].unique())
    groupsLwr = [i.lower() for i in list(df[groupName].values)] 
    #groupsLwr = [i.lower() for i in groups]
    grpvalues = list(df['lowerNAME'].values)
    grpkeys = list(df[groupName].values)
    f = {}
    for i in range(len(groups)):
        f[groupsLwr[i]] = list(df[df[groupName]==groups[i]]['lowerNAME'])
    return f,groupsLwr, grpvalues, grpkeys

# %%
parList1 = ListMake(SDWISlist, "parameter_nm", "parameter_group_nm")
parList2 = ListMake(NWISlist, "parm_nm", "group")
parList3 = ListMake(SDWISlist, "srsname", "parameter_group_nm")

# %%
groupsLwr = parList1[1] + parList2[1] + parList3[1]
grpvalues = parList1[2] + parList2[2] + parList3[2]
grpkeys = parList1[3] + parList2[3] + parList3[3]


parlist = sorted(list(set(parList1[1] + parList2[1] + parList3[1])))
parlistValues = sorted(list(set(parList1[2] + parList2[2] + parList3[2])))
parlistKeys = sorted(list(set(parList1[3] + parList2[3] + parList3[3])))

# %%
print(len(groupsLwr), len(grpvalues), len(grpkeys))
# Out:
# (23794, 23794, 23794)

# %%
allParameters = dict(zip(grpvalues,groupsLwr))

# %%
z = parList1[0].copy()
z.update(parList2[0])
z.update(parList3[0])

# %%
z
# Out:
# {'biological': ['biomass, periphyton, ash weight, grams per square meter',
#   'biomass, periphyton, dry weight, grams per square meter',
#   'dead fish, severity, code',
#   'average length of biological tissue samples in composite, centimeters',
#   'average weight of biological tissue samples in composite, grams',
#   'bighead carp (hypophthalmichthys nobilis), count of tagged fish per hour (count may include repeats of same fish)',
#   'silver carp (hypophthalmichthys molitrix), count of tagged fish per hour (count may include repeats of same fish)',
#   'hybrid asian carp (hypophthalmichthys nobliis and hypophthalmichthys molitrix hybrids), count of tagged fish per hour (count may include repeats of same fish)',
#   'sum of bighead, silver and hybrid carp, count of tagged fish per hour (count may include repeats of same fish)',
#   'shovelnose sturgeon (scaphirhynchus platorynchus), count of tagged fish per hour (count may include repeats of same fish)',
#   'bighead carp (hypophthalmichthys nobilis), count of unique tagged fish per hour (same fish are not counted more than once per hour)',
#   'silver carp (hypophthalmichthys molitrix), count of unique tagged fish per hour (same fish are not counted more than once per hour)',
#   'hybrid asian carp (hypophthalmichthys nobliis and hypophthalmichthys molitrix hybrids), count of unique tagged fish per hour (same fish are not counted more than once per',
#   'sum of bighead, silver and hybrid carp, count of unique tagged fish per hour (same fish are not counted more than once per hour)',
#   'shovelnose sturgeon (scaphirhynchus platorynchus), count of unique tagged fish per hour (same fish are not counted more than once per hour)',
#   'chytrid fungus (batrachochytrium dendrobatidis), water, quantitative polymerase chain reaction (qpcr) method, copies per milliliter',
#   'chlorophyll a, water, fluorometric method, corrected, micrograms per liter',
#   'chlorophyll a, water, trichromatic method, uncorrected, micrograms per liter',
#   'chlorophyll a, phytoplankton, spectrophotometric acid method, micrograms per liter',
#   'pheophytin a, fluorometric method, micrograms per liter',
#   'chlorophyll a, fluorometric method, uncorrected, micrograms per liter',
#   'pheophytin a, phytoplankton, spectrophotometric acid method, micrograms per liter',
#   'chlorophyll a, periphyton, spectrophotometric method, corrected, milligrams per square meter',
#   'pheophytin a, periphyton, spectrophotometric acid method, corrected, milligrams per square meter',
#   'chlorophylls, periphyton, spectrophotometric method, uncorrected, milligrams per square meter',
#   'chlorophyll b, periphyton, spectrophotometric method, uncorrected, milligrams per square meter',
#   'chlorophyll c, periphyton, spectrophotometric method, uncorrected, milligrams per square meter',
#   'chlorophyll a, periphyton, spectrophotometric method, uncorrected, milligrams per square meter',
#   'chlorophyll a, phytoplankton, spectrophotometric method, uncorrected, micrograms per liter',
#   'chlorophyll b, phytoplankton, spectrophotometric method, micrograms per liter',
#   'chlorophyll c, phytoplankton, spectrophotometric method, micrograms per liter',
#   'chlorophylls, phytoplankton, spectrophotometric method, uncorrected, micrograms per liter',
#   'chlorophylls, periphyton, fluorometric method, uncorrected, milligrams per square meter',
#   'chlorophyll a, periphyton, fluorometric method, corrected, milligrams per square meter',
#   'pheophytin a, periphyton, fluorometric method, milligrams per square meter',
#   'pheophytin a, plankton in water, milligrams per cubic meter',
#   'chlorophyll a, plankton in water, milligrams per cubic meter',
#   'chlorophylls less than 35 microns, 35-um sieve prefilter, phytoplankton, fluorometric method, micrograms per liter',
#   'chlorophyll a less than 35 microns, 35-um sieve prefilter, phytoplankton, fluorometric method, corrected, micrograms per liter',
#   'pheophytin a less than 35 microns, 35-um sieve prefilter, phytoplankton, fluorometric method, micrograms per liter',
#   'chlorophylls less than 11 microns, 11-um sieve prefilter, phytoplankton, fluorometric method, micrograms per liter',
#   'chlorophyll a less than 11 microns, 11-um sieve prefilter, phytoplankton, fluorometric method, corrected, micrograms per liter',
#   'pheophytin a less than 11 microns, 11-um sieve prefilter, phytoplankton, fluorometric method, micrograms per liter',
#   'chlorophylls greater than 35 microns, calculated as chlorophylls (p32217) less chlorophylls <35 um (p32271), micrograms per liter',
#   'chlorophyll a greater than 35 microns, calculated as chlorophyll a (p32209) less chlorophyll a <35 um (p32272), micrograms per liter',
#   'pheophytin a greater than 35 microns, calculated as pheophytin a (p32213) less pheophytin a <35 um (p32273), micrograms per liter',
#   'chlorophylls greater than 11 microns, calculated as chlorophylls (p32217) less chlorophylls <11 um (p32274), micrograms per liter',
#   'chlorophyll a greater than 11 microns, calculated as chlorophyll a (p32209) less chlorophyll a <11 um (p32275), micrograms per liter',
#   'pheophytin a greater than 11 microns, calculated as pheophytin a (p32213) less pheophytin a <11 um (p32276), micrograms per liter',
#   'chlorophyll, total, water, in situ, fluorometric, 650-700 nm, relative fluorescence units (rfu)',
#   'chlorophyll a, total, in situ, fluorescence excitation at 370, 470, 525, 570, 590, 610 nm, fluorescence emission at 700 nm with correction for cdom, ug/l',
#   'chlorophyll a, green algae, in situ, fluorescence excitation at 370, 470, 525, 570, 590, 610 nm, fluorescence emission at 700 nm with correction for cdom, ug/l',
#   'chlorophyll a, cyanobacteria, in situ, fluorescence excitation at 370, 470, 525, 570, 590, 610 nm, fluorescence emission at 700 nm with correction for cdom, ug/l',
#   'chlorophyll a, cryptophytes, in situ, fluorescence excitation at 370, 470, 525, 570, 590, 610 nm, fluorescence emission at 700 nm with correction for cdom, ug/l',
#   'chlorophyll a, diatoms and dinoflagellates, in situ, excitation at 370, 470, 525, 570, 590, 610 nm, fluorescence emission at 700 nm with correction for cdom, ug/l',
#   'chlorophyll a, estimated, water, in-situ, in-vivo fluorescence (ivf), relative fluorescence units (rfu)',
#   'chlorophyll a, estimated, water, in-situ, in-vivo fluorescence (ivf), concentration estimated from reference material, micrograms per liter',
#   'chlorophyll a, modeled, water, in-situ, in-vivo fluorescence (ivf), concentration modeled from field samples analyzed by extraction, micrograms per liter',
#   'chlorophylls, water, in situ, fluorometric method, excitation at 470 +-15 nm, emission at 685 +-20 nm, micrograms per liter',
#   'phycocyanins (cyanobacteria), water, in situ, fluorometric method, excitation at 590 +-15 nm, emission at 685 +-20 nm, micrograms per liter',
#   'chlorophylls, water, in situ, fluorometric method, excitation at 470 +-15 nm, emission at 685 +-20 nm, relative fluorescence units (rfu)',
#   'phycocyanins (cyanobacteria), water, in situ, fluorometric method, excitation at 590 +-15 nm, emission at 685 +-20 nm, relative fluorescence units (rfu)',
#   'females, in sample or catch, number',
#   'males, in sample or catch, number',
#   'water present, biota, tissue, recoverable, dry weight, percent',
#   'biomass, phytoplankton, ash free dry mass, milligrams per liter',
#   'biomass, periphyton, ash free dry mass, grams per square meter',
#   'geosmin, water, filtered (0.7 micron glass fiber filter), recoverable, nanograms per liter',
#   'cyanobacteria, water, copies per 100 milliliters (cp/100 ml)',
#   'microcystis, water, copies per 100 milliliters (cp/100 ml)',
#   'microcystis mcye toxin gene, water, dna based, copies per 100 milliliters (cp/100 ml)',
#   'microcystis mcye toxin gene, water, rna based, copies per 100 milliliters (cp/100 ml)',
#   'anabaena mcye toxin gene, water, dna based, copies per 100 milliliters (cp/100 ml)',
#   'anabaena mcye toxin gene, water, rna based, copies per 100 milliliters (cp/100 ml)',
#   'planktothrix mcye toxin gene, water, dna based, copies per 100 milliliters (cp/100 ml)',
#   'planktothrix mcye toxin gene, water, rna based, copies per 100 milliliters (cp/100 ml)',
#   'phytoplankton, total, cells per milliliter',
#   'specimen length, average of composite, biota, millimeters',
#   'specimen length, total of composite, biota, millimeters',
#   'specimen weight, average of composite, biota, grams',
#   'specimen weight, total of composite, biota, grams',
#   'standard fish length, average of composite, biota, millimeters',
#   'standard fish length, total of composite, biota, millimeters',
#   'individuals without anomalies, biota, number in sample',
#   'individuals with popeye disease, biota, number in sample',
#   'individuals with blindness, excluding popeye disease, biota, number in sample',
#   'individuals with external deformities, biota, number in sample',
#   'individuals with eroded fins, biota, number in sample',
#   'individuals with external lesions or ulcers, biota, number in sample',
#   'individuals with fungus, biota, number in sample',
#   'individuals with leeches, biota, number in sample',
#   'individuals with black spot, biota, number in sample',
#   'individuals with anchor worms, biota, number in sample',
#   'individuals with external tumors, biota, number in sample',
#   'individuals with ich, biota, number in sample',
#   'individuals with other external parasites, biota, number in sample',
#   'pheophytin a, periphyton, milligrams per square meter',
#   'pheophytin a, phytoplankton, micrograms per liter',
#   'chlorophyll, total, water, fluorometric, 650-700 nanometers, in situ sensor, micrograms per liter',
#   'mean age of organisms in composite sample, years',
#   'minimum age of organisms in composite sample, years',
#   'maximum age of organisms in composite sample, years',
#   'chlorophyll a, periphyton, depositional-targeted habitat (dth), chromatographic-fluorometric method, milligrams per square meter',
#   'pheophytin a, periphyton, depositional-targeted habitat (dth), chromatographic-fluorometric method, milligrams per square meter',
#   'biomass, periphyton, ash weight, depositional-targeted habitat (dth), grams per square meter',
#   'biomass, periphyton, ash free dry weight, depositional-targeted habitat (dth), grams per square meter',
#   'biomass, periphyton, dry weight, depositional-targeted habitat (dth), grams per square meter',
#   'chlorophyll b, water, unfiltered, trichromatic method, uncorrected, micrograms per liter',
#   'chlorophyll c, water, unfiltered, trichromatic method, uncorrected, micrograms per liter',
#   'chlorophyll a, water, in situ, in vivo fluorescence, in vivo fluorescence units',
#   'chlorophyll a, water, in situ, in vivo fluorescence, micrograms per liter',
#   'invertebrates, benthic, wet weight, grams per square meter',
#   'invertebrates, benthic, dry weight, grams per square meter',
#   'invertebrates, benthic, ash weight, grams per square meter',
#   'invertebrates, benthic, organisms per square meter',
#   'macrophytes, total, number per square meter',
#   'periphyton, total, number of cells per square millimeter',
#   'zooplankton, total, number of organisms per cubic meter',
#   'zooplankton, dry weight, grams per cubic meter',
#   'zooplankton, ash weight, grams per cubic meter',
#   'biomass/chlorophyll ratio, plankton, number',
#   'biomass/chlorophyll ratio, periphyton, number',
#   'chlorophyll a, phytoplankton, chromatographic-spectrophotometric method, micrograms per liter',
#   'chlorophyll b, phytoplankton, chromatographic-spectrophotometric method, micrograms per liter',
#   'chlorophyll a, phytoplankton, chromatographic-fluorometric method, micrograms per liter',
#   'chlorophyll b, phytoplankton, chromatographic-fluorometric method, micrograms per liter',
#   'chlorophyll a, periphyton, chromatographic-spectrophotometric method, milligrams per square meter',
#   'chlorophyll b, periphyton, chromatographic-spectrophotometric method, milligrams per square meter',
#   'chlorophyll a, periphyton, chromatographic-fluorometric method, milligrams per square meter',
#   'chlorophyll b, periphyton, chromatographic-fluorometric method, milligrams per square meter',
#   'productivity, primary, gross, milligrams oxygen per cubic meter per day',
#   'productivity, primary, gross, milligrams oxygen per square meter per day',
#   'productivity, primary, gross, milligrams carbon per cubic meter per day',
#   'productivity, primary, gross, milligrams carbon per square meter per day',
#   'productivity, primary, net, milligrams oxygen per cubic meter per day',
#   'productivity, primary, net, milligrams oxygen per square meter per day',
#   'productivity, primary, net, milligrams carbon per cubic meter per day',
#   'productivity, primary, net, milligrams carbon per square meter per day',
#   'respiration, milligrams oxygen per cubic meter per day',
#   'respiration, milligrams oxygen per square meter per day',
#   'algal growth potential, milligrams per liter',
#   'seston, water, unfiltered, total, milligrams per liter',
#   'seston, water, unfiltered, ash weight, milligrams per liter',
#   'cosmarium species, water, number per liter',
#   'length of organism, maximum in composite sample, centimeters',
#   'length of organisms, standard deviation, composite sample, centimeters',
#   'weight of organism, minimum in composite sample, grams',
#   'weight of organism, maximum in composite sample, grams',
#   'weight of organisms, standard deviation, composite sample, grams',
#   'length of organism, minimum in composite sample, centimeters',
#   'biomass, plankton, ash weight, milligrams per liter',
#   'biomass, plankton, dry weight, milligrams per liter',
#   'individuals in sample, biota, number',
#   'species, different in sample, number',
#   'diatoms, periphyton, number per square millimeter',
#   'carbon production in plants, photosynthesis, carbon-14, milligrams of carbon per square meter',
#   'age of organism, years',
#   'floating vegetation, severity, code',
#   'algal growth potential, usgs modified bottle test, water, filtered, milligrams per liter',
#   'weight of organism, total, grams',
#   'weight of sampled tissue from organism, grams',
#   'length of organism, centimeters',
#   'chlorophyll a, fluorometric method, corrected, area weighted average, micrograms per liter',
#   'pheophytin a, fluorometric method, area weighted average, micrograms per liter',
#   'chlorophyll a, fluorometric method, uncorrected, area weighted average, micrograms per liter',
#   'dreissena  beneden, 1835, count',
#   'dreissena polymorpha (pallas, 1771) adults, number per square meter',
#   'dreissena polymorpha (pallas, 1771) larvae, number per liter',
#   'dreissena bugensis  andrusov, 1897 adults, number per square meter',
#   'dreissena bugensis  andrusov, 1897 larvae, number per liter',
#   'cyanobacteria (blue-green algae), hydrolab in vivo fluorescence of phycocyanin, excitation at 590 nm, emission at 650 nm, cells per milliliter',
#   'cyanobacteria (blue-green algae), ysi in vivo fluorescence of phycocyanin, excitation at 595, emission at 650 nm, cells per milliliter',
#   'phycocyanins (cyanobacteria), turner designs scufa in vivo fluorescence of phycocyanin, excitation at 595 nm, emission at 670 nm, micrograms per liter',
#   'phycocyanins (cyanobacteria), water, in situ, in vivo fluorescence, in vivo fluorescence units',
#   'chlorophyll, total, estimated load, fluorometric probe method, water, calculated, pounds per day'],
#  'information': ['nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  'inorganics, major, metals': ['calcium',
#   'calcium',
#   'calcium',
#   'calcium',
#   'calcium',
#   'calcium',
#   'calcium',
#   'calcium',
#   'magnesium',
#   'magnesium',
#   'sodium',
#   'sodium',
#   'magnesium',
#   'magnesium',
#   'sodium',
#   'sodium',
#   'sodium',
#   'sodium',
#   'calcium',
#   'calcium',
#   'magnesium',
#   'sodium',
#   'sodium',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'calcium',
#   'calcium',
#   'magnesium',
#   'sodium',
#   'sodium'],
#  'inorganics, major, non-metals': ['carbon dioxide',
#   'chloride',
#   'fluoride',
#   'fluoride',
#   'silica',
#   'silica',
#   'silica',
#   'chlorine',
#   'chlorine',
#   'chlorine',
#   'chlorine',
#   'chlorine',
#   'chlorine',
#   'chlorine',
#   'chlorine',
#   'chlorine',
#   'chlorine',
#   'chlorine',
#   'chlorine',
#   'carbon dioxide',
#   'silica',
#   'bromide',
#   'nan',
#   'chloride',
#   'bromide',
#   'nan',
#   'silica',
#   'carbon dioxide',
#   'carbon dioxide',
#   'bromide',
#   'chloride',
#   'fluoride',
#   'chloride',
#   'silica',
#   'chloride',
#   'chlorine',
#   'chlorine',
#   'chlorine',
#   'chlorine',
#   'chloride'],
#  'inorganics, minor, metals': ['vanadium',
#   'beryllium',
#   'barium',
#   'barium',
#   'barium',
#   'beryllium',
#   'beryllium',
#   'bismuth',
#   'bismuth',
#   'cadmium',
#   'cadmium',
#   'chromium',
#   'chromium',
#   'chromium',
#   'chromium(vi)',
#   'chromium',
#   'chromium',
#   'chromium',
#   'cobalt',
#   'cobalt',
#   'copper',
#   'copper',
#   'copper',
#   'copper',
#   'iron',
#   'iron',
#   'iron',
#   'iron',
#   'iron',
#   'iron',
#   'lead',
#   'lead',
#   'lead',
#   'lead',
#   'manganese',
#   'manganese',
#   'manganese',
#   'manganese',
#   'thallium',
#   'thallium',
#   'molybdenum',
#   'molybdenum',
#   'nickel',
#   'nickel',
#   'nickel',
#   'silver',
#   'silver',
#   'silver',
#   'strontium',
#   'strontium',
#   'strontium',
#   'vanadium',
#   'vanadium',
#   'zinc',
#   'zinc',
#   'zinc',
#   'tin',
#   'tin',
#   'aluminum',
#   'aluminum',
#   'aluminum',
#   'cadmium',
#   'lead',
#   'lead',
#   'chromium',
#   'chromium',
#   'chromium',
#   'copper',
#   'copper',
#   'manganese',
#   'manganese',
#   'thallium',
#   'molybdenum',
#   'lithium',
#   'lithium',
#   'lithium',
#   'titanium',
#   'titanium',
#   'aluminum',
#   'iron',
#   'iron',
#   'iron',
#   'mercury',
#   'mercury',
#   'iron',
#   'iron',
#   'iron',
#   'aluminum',
#   'barium',
#   'cadmium',
#   'cobalt',
#   'chromium',
#   'chromium',
#   'chromium',
#   'copper',
#   'copper',
#   'manganese',
#   'manganese',
#   'molybdenum',
#   'nickel',
#   'lead',
#   'lead',
#   'strontium',
#   'zinc',
#   'lithium',
#   'strontium',
#   'manganese',
#   'manganese',
#   'iron',
#   'iron',
#   'iron',
#   'mercury',
#   'mercury',
#   'mercury',
#   'iron',
#   'iron',
#   'iron',
#   'chromium(vi)',
#   'iron',
#   'iron',
#   'iron',
#   'iron',
#   'iron',
#   'iron',
#   'iron',
#   'iron',
#   'iron',
#   'iron',
#   'iron',
#   'iron',
#   'silver'],
#  'inorganics, minor, non-metals': ['cyanide',
#   'nan',
#   'cyanide',
#   'cyanide',
#   'arsenic',
#   'boron',
#   'arsenic',
#   'arsenic',
#   'boron',
#   'boron',
#   'antimony',
#   'antimony',
#   'selenium',
#   'selenium',
#   'asbestos',
#   'asbestos',
#   'arsenic',
#   'boron',
#   'cyanide',
#   'antimony'],
#  'microbiological': ['total coliforms, m-endo mf method, immediate, water, colonies per 100 milliliters',
#   'total coliforms, m-endo mf method, delayed, water, colonies per 100 milliliters',
#   'total coliforms, les endo method, immediate, water, colonies per 100 milliliters',
#   'total coliforms, brilliant green lactose broth method, confirmed, water, most probable number per 100 milliliters',
#   'total coliforms, completed test, water, most probable number per 100 milliliters',
#   'fecal coliforms, m-fc mf (0.7 micron) method, water, colonies per 100 milliliters',
#   'fecal coliforms, ec broth method, water, most probable number per 100 milliliters',
#   'fecal coliforms, m-fc mf (0.45 micron) method, water, colonies per 100 milliliters',
#   'fecal coliforms, eijkman test, 44.5 degrees celsius, water, most probable number per 100 milliliters',
#   'fecal coliforms, boric acid lactose broth, 43 degrees celsius, water, most probable number per 100 milliliters',
#   'fecal coliforms, a-1 broth method, 44.5 degrees celsius, 24 hours, water, most probable number per 100 milliliters',
#   'fecal coliforms, m-fc mf (0.7 micron) method, water, colonies per 100 milliliters',
#   'escherichia coli, m-tec mf method, water, colonies per 100 milliliters',
#   'escherichia coli, m-tec mf method, water, colonies per 100 milliliters',
#   'enterococci, m-e mf method, water, colonies per 100 milliliters',
#   'fecal streptococci, kf streptococcus mf method, water, colonies per 100 milliliters',
#   'fecal streptococci, azide-dextrose-ethyl-violet azide broth method, water, most probable number per 100 milliliters',
#   'fecal streptococci, azide-dextrose-ethyl-violet azide broth method, tube configuration, water, code',
#   'fecal streptococci, m-enterococcus mf method, water, colonies per 100 milliliters',
#   'salmonella, water, 0.45 micron filter method, most probable number per 100 milliliters',
#   'escherichia coli o157, presumptive test, water, 0.45 micron filter method, presence or absence per 500 milliliters',
#   'escherichia coli o157, confirmed test, water, 0.45 micron filter, presence or absence per 500 milliliters',
#   'escherichia coli, mug method, water, presence or absence in sample',
#   'fecal coliforms, ec medium, 44.5 degrees celsius, 24 hours, standard methods 9221e.1, water, most probable number per 100 milliliters',
#   'total coliforms, water, most probable number per 100 milliliters',
#   'fecal coliforms, water, most probable number per 100 milliliters',
#   'fecal streptococci, water, most probably number per 100 milliliters',
#   'escherichia coli, water, most probable number per 100 milliliters',
#   'escherichia coli, water, colonies per 100 milliliters',
#   'heterotrophic plate count, water, colony forming units per milliliter',
#   'escherichia coli, water, m-coliblue method, colonies per 100 milliliters',
#   'total coliforms, water, m-coliblue method, colonies per 100 milliliters',
#   'iron-related bacteria, water, biotester, colony forming units per milliliter',
#   'iron-related bacteria reaction pattern signature, biotester, water, code',
#   'sulfate-reducing bacteria, water, biotester, colony forming units per milliliter',
#   'sulfate-reducing bacteria reaction pattern signature, water, biotester, code',
#   'slime-forming bacteria reaction pattern signature, water, biotester, code',
#   'slime-forming bacteria, water, biotester, colony forming units per milliliter',
#   'giardia, water, pcr method, vortexed, detection/no detection',
#   'giardia, sediment, pcr method, vortexed, detection/no detection',
#   'cryptosporidium, water, pcr method, vortexed, detection/no detection',
#   'cryptosporidium, sediment, pcr method, vortexed, detection/no detection',
#   'legionella, water, pcr method, centrifuged, detection/no detection',
#   'legionella, sediment, pcr method, centrifuged, detection/no detection',
#   'avian influenza, h5 and h7, water, centrifuged, rt-pcr method, detection/no detection',
#   'avian influenza, h5 and h7, sediment, centrifuged, rt-pcr method, detection/no detection',
#   'avian influenza, h5 and h7, fecal swab, centrifuged, rt-pcr method, detection/no detection',
#   'campylobacter, water, pcr method, colony forming units per 100 milliliters',
#   'campylobacter, sediment, pcr method, wet weight, colony forming units per gram',
#   'human enterovirus, water, copies per liter (cp/l)',
#   'human norovirus genogroup ia, water, copies per liter (cp/l)',
#   'total culturable virus, water, most probable number per liter',
#   'enterococcus species, water, calibrator cell equivalents per 100 milliiters (cce/100 ml)',
#   'nitrate-reducing bacteria, borehole cuttings, wet sieved, wet weight, most probable number per gram',
#   'denitrifying bacteria, borehole cuttings, wet sieved, wet weight, most probable number per gram',
#   'enterococci, fluorogenic substrate presence or absence method, water, presence or absence in 100 milliliters',
#   'aerobic endospores, water, colony forming units per 100 milliliters',
#   'bacteria, total plate count, tpc agar, 35 degrees celsius, 24 hours, water, colonies per milliliter',
#   'human adenovirus group a, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'human adenovirus group b, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'human adenovirus groups c, d, f, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'human enterovirus, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'norovirus genogroup i, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'norovirus genogroup ii, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'human polyomavirus, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'human-associated hf183 bacteroides, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'bovine viral diarrhea virus type 1, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'bovine viral diarrhea virus type 2, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'bovine rotavirus group a, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'bovine coronavirus, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'bovine adenovirus, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'bovine enterovirus, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'bovine polyomavirus, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'bovine bacteroides, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'bovine-associated m3 bacteria, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'enterococcus, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'pepper mild mottle virus, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'enterohemorrhagic e. coli, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'salmonella, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'campylobacter jejuni, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'cryptosporidium parvum, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'giardia lamblia, water, quantitative polymerase chain reaction (qpcr) method, copies per liter',
#   'human norovirus genogroup ib (gib), water, copies per liter (cp/l)',
#   'human norovirus genogroup ii (gii), water, copies per liter (cp/l)',
#   'anabaena, water, copies per 100 milliliters (cp/100 ml)',
#   'bacteria, denitrifying, water, most probable number',
#   'bacteria, nitrifying, water, most probable number',
#   'bacteria, sulfate reducing, water, most probable number',
#   'total coliforms, onpg-mug method, water, colonies per 100 milliliters',
#   'escherichia coli, m-tec mf method, water, colonies per 100 milliliters',
#   'escherichia coli, na-mug mf method, water, colonies per 100 milliliters',
#   'escherichia coli, m-tec mf method, bed sediment, dry weight, colonies per gram',
#   'escherichia coli, defined substrate test method (dstm), bed sediment, dry weight, most probable number per gram',
#   'escherichia coli, defined substrate test method (dstm), water, most probable number per 100 milliliters',
#   'fecal coliforms, m-fc mf method, bed sediment, dry weight, colonies per gram',
#   'total coliforms, defined substrate test method (dstm), water, most probable number per 100 milliliters',
#   'escherichia coli, water, calibrator cell equivalents per 100 milliliters (cce/100 ml)',
#   'escherichia coli, water, cell equivalents per 100 milliliters (ce/100 ml)',
#   'total coliforms, water, colonies per 100 milliliters',
#   'fecal streptococci, water, colonies per 100 milliliters',
#   'fecal coliforms, water, colonies per 100 milliliters',
#   'giardia, water, 0.30 micron filter method, cysts per 100 liters',
#   'cryptosporidium, water, 0.30 micron filter method, oocysts per 100 liters',
#   'glycol hydrolyzing bacteria, water, colonies per 100 milliliters',
#   'pseudomonas, water, colonies per 100 milliliters',
#   'presumptive aeromonas, water, colonies per 100 milliliters',
#   'escherichia coli, modified mtec mf method, bed sediment, dry weight, colonies per gram',
#   'enterococci, mei mf method, bed sediment, dry weight, colonies per gram',
#   'actinomycetes, standard plate count, double agar layer, water, colonies per milliliter',
#   'bacteroides general marker, allbac, water, 0.4 micron filter method, copies per 100 milliters (cp/100 ml)',
#   'bacteroides general marker, genbac, water, 0.4 micron filter method, copies per 100 milliters (cp/100 ml)',
#   'bacteroides human marker, qhf183, water, 0.4 micron filter method, copies per 100 milliters (cp/100 ml)',
#   'bacteroides human marker, bachum, water, 0.4 micron filter method, copies per 100 milliters (cp/100 ml)',
#   'bacteroides bovine marker, bobac, water, 0.4 micron filter method, copies per 100 milliters (cp/100 ml)',
#   'bacteroides dog marker, baccan, water, 0.4 micron filter method, copies per 100 milliters (cp/100 ml)',
#   'brevibacterium poultry marker, la-35, water, 0.4 micron filter method, copies per 100 milliters (cp/100 ml)',
#   'catellicoccus gull marker, gull2, water, 0.4 micron filter method, copies per 100 milliters (cp/100 ml)',
#   'bacteroides canada goose marker, cgof1-bac, water, 0.4 micron filter method, copies per 100 milliters (cp/100 ml)',
#   'bacteroides canada goose marker, cgof2-bac, water, 0.4 micron filter method, copies per 100 milliters (cp/100 ml)',
#   'salmonella, mf method, water, colonies per 100 milliliters',
#   'pseudomonas aeruginosa, mf method, water, colonies per 100 milliliters',
#   'heterotrophic bacteria, r2 agar method, water, colony forming units per milliliter',
#   'enterobacter cloacae, mf method, water, colonies per 100 milliliters',
#   'pseudomonas aeruginosa, water, most probable number per 100 milliliters',
#   'bacteria, total count, epifluorescence, water, cells per milliliter',
#   'nitrosomonas, water, most probable number per 100 milliliters',
#   'nitrobacter, water, most probable number per 100 milliliters',
#   'total coliforms, water, presence or absence',
#   'enterobacter agglomerans, mf method, water, presence or absence',
#   'klebsiella pneumoniae, mf method, water, presence or absence',
#   'total coliforms, water, presence or absence in sample',
#   'fecal coliforms, water, presence or absence in sample',
#   'fecal streptococci, water, presence or absence in sample',
#   'escherichia coli, water, presence or absence in sample',
#   'total coliforms, mi mf method, water, colonies per 100 milliliters',
#   'escherichia coli, mi mf method, water, colonies per 100 milliliters',
#   'escherichia coli, modified m-tec mf method, water, colonies per 100 milliliters',
#   'coliphage, e. coli, c13 host, mf method, water, plaques per 100 milliliters',
#   'coliphage, e. coli, famp host, mf method, water, plaques per 100 milliliters',
#   'coliphage, e. coli, c-host, mf method, water, plaques per 100 milliliters',
#   'total coliforms, defined substrate test method (dstm), water, most probable number per 100 milliliters',
#   'enterococci, mei mf method, water, colonies per 100 ml',
#   'enteric virus, total culturable, bgm kidney cell culture, 1-mds filter, quantal assay, 37 degrees celsius, water, most probable number per 100 liters',
#   'coliphage, e. coli, c-host, 1-mds filter, agar overlay, 37 degrees celsius, water, plaque-forming units per 100 liters',
#   'coliphage, e. coli, c-3000 host, 1-mds filter, agar overlay, 37 degrees celsius, water, plaque-forming units per 100 liters',
#   'clostridium perfringens, mcp mf method, water, colonies per 100 milliliters',
#   'total cell count, water, cells per milliliter',
#   'coliphage, somatic, e. coli c-host, 2-step enrichment, water, presence or absence in 100 milliliters',
#   'coliphage, somatic, e. coli c-host, 2-step enrichment, water, presence or absence per liter',
#   'coliphage, somatic, e. coli c-host, 2-step enrichment, water, presence or absence in 4 liters',
#   'coliphage, somatic, e. coli cn13-host, 2-step enrichment, water, presence or absence in 100 milliliters',
#   'coliphage, somatic, e. coli cn13-host, 2-step enrichment, water, presence or absence per liter',
#   'coliphage, somatic, e. coli cn13-host, 2-step enrichment, water, presence or absence in 4 liters',
#   'coliphage, f-specific, e. coli famp-host, 2-step enrichment, water, presence or absence in 100 milliliters',
#   'coliphage, f-specific, e. coli famp-host, 2-step enrichment, water, presence or absence per liter',
#   'coliphage, f-specific, e. coli famp-host, 2-step enrichment, water, presence or absence in 4 liters',
#   'fecal coliforms, estimated by regression equation, water, colonies per 100 milliliters',
#   'escherichia coli, estimated by regression equation, water, colonies per 100 milliliters',
#   'fecal coliforms, estimated load, water, billions of colonies per day',
#   'escherichia coli, estimated load, water, calculated, billions of colonies per day',
#   'total coliforms, defined substrate test presence or absence method (dstm pa), water, presence or absence per 100 milliliters',
#   'escherichia coli, defined substrate test presence or absence method (dstm pa), water, presence or absence per 100 milliliters',
#   'giardia, method 1623, water, cysts per 10 liters',
#   'giardia, spike efficiency, parameter code 99597, percent recovery',
#   'cryptosporidium, method 1623, water, oocysts per 10 liters',
#   'cryptosporidium, spike efficiency, parameter code 99599, percent recovery',
#   'enterococci, defined substrate test method (dstm), water, most probable number per 100 milliliters',
#   'helicobacter pylori, fluorescent antibody method, water, organisms per milliliters',
#   'cryptosporidium, capsule filter, method 1622, water, oocysts per 10 liters',
#   'cryptosporidium, spike efficiency, parameter code 99761, percent recovery',
#   'cryptosporidium, mf, method 1622, water, oocysts per 10 liters',
#   'cryptosporidium, spike efficiency, parameter code 99763, percent recovery',
#   'clostridium perfringens, ethanol treated, mcp mf method, ammonium hydroxide, 42 degrees celsius, water, colonies per 100 milliliters',
#   'enterovirus, reverse-transcriptase polymerase chain reaction method, 1mds filter, water, presence or absence in 50 liters',
#   'reovirus, reverse-transcriptase polymerase chain reaction method, 1mds filter, water, presence or absence in 50 liters',
#   'rotavirus, reverse-transcriptase polymerase chain reaction method, 1mds filter, water, presence or absence in 50 liters',
#   'hepatitis-a virus, reverse-transcriptase polymerase chain reaction method, 1mds filter, water, presence or absence in 50 liters',
#   'norwalk virus, reverse-transcriptase polymerase chain reaction method, 1mds filter, water, presence or absence in 50 liters',
#   'calicivirus, reverse-transcriptase polymerase chain reaction method, 1mds filter, water, presence or absence in 50 liters'],
#  'nutrient': ['nitrogen',
#   'nitrogen',
#   'nitrogen',
#   'nitrogen',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'nitrogen',
#   'nitrogen',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'nitrogen',
#   'nitrogen',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate',
#   'phosphate'],
#  'organics, other': ['acetic acid',
#   '2-methylnaphthalene',
#   'o-nitroaniline',
#   'p-nitroaniline',
#   '2-chloroethyl vinyl ether',
#   '2-chloroethyl vinyl ether',
#   'chloromethane',
#   'p-nitroaniline',
#   'dichlorobromomethane',
#   'carbon tetrachloride',
#   'tribromomethane',
#   'chlorodibromomethane',
#   'chloroform',
#   'toluene',
#   'benzene',
#   'acenaphthylene',
#   'acenaphthylene',
#   'acenaphthene',
#   'acenaphthene',
#   'acrolein',
#   'acrolein',
#   'anthracene',
#   'anthracene',
#   'benzo(b)fluoranthene',
#   'benzo(b)fluoranthene',
#   'benzene',
#   'benzidine',
#   'benzo[k]fluoranthene',
#   'benzo[k]fluoranthene',
#   'benzo[a]pyrene',
#   'benzo[a]pyrene',
#   'bis(chloromethyl) ether',
#   'bis(chloromethyl) ether',
#   'bis(2-chloroethyl) ether',
#   'bis(2-chloroethyl) ether',
#   'bis(2-chloroethoxy)methane',
#   'bis(2-chloroethoxy)methane',
#   'tribromomethane',
#   'butyl benzyl phthalate',
#   'butyl benzyl phthalate',
#   'carbon tetrachloride',
#   'chlorobenzene',
#   'chlorobenzene',
#   'chlorodibromomethane',
#   'chloroethane',
#   'chloroethane',
#   'chloroform',
#   'chrysene',
#   'chrysene',
#   'dibutyl phthalate',
#   'dichlorobromomethane',
#   'cfc-12',
#   'diethyl phthalate',
#   'diethyl phthalate',
#   'dimethyl phthalate',
#   'dimethyl phthalate',
#   'ethylbenzene',
#   'ethylbenzene',
#   'fluoranthene',
#   'fluoranthene',
#   'fluorene',
#   'fluorene',
#   'hexachlorocyclopentadiene',
#   'hexachlorocyclopentadiene',
#   'hexachlorobutadiene',
#   'hexachlorobutadiene',
#   'hexachloroethane',
#   'hexachloroethane',
#   'indeno[1,2,3-cd]pyrene',
#   'indeno[1,2,3-cd]pyrene',
#   'isophorone',
#   'isophorone',
#   'chloromethane',
#   'chloromethane',
#   'methylene chloride',
#   'methylene chloride',
#   'n-nitrosodi-n-propylamine',
#   'n-nitrosodi-n-propylamine',
#   'n-nitrosodiphenylamine',
#   'n-nitrosodiphenylamine',
#   'n-nitrosodimethylamine',
#   'n-nitrosodimethylamine',
#   'naphthalene',
#   'nitrobenzene',
#   'nitrobenzene',
#   'phenanthrene',
#   'phenanthrene',
#   'pyrene',
#   'pyrene',
#   'tetrachloroethylene',
#   'tetrachloroethylene',
#   'toluene',
#   'trichloroethylene',
#   'cfc-11',
#   'cfc-11',
#   'vinyl chloride',
#   '1,1-dichloroethane',
#   '1,1-dichloroethane',
#   '1,1-dichloroethylene',
#   '1,1-dichloroethylene',
#   '1,1,1-trichloroethane',
#   '1,1,1-trichloroethane',
#   '1,1,2-trichloroethane',
#   '1,1,2-trichloroethane',
#   '1,1,2,2-tetrachloroethane',
#   '1,1,2,2-tetrachloroethane',
#   'benzo[ghi]perylene',
#   'benzo[ghi]perylene',
#   'benz[a]anthracene',
#   'benz[a]anthracene',
#   'o-dichlorobenzene',
#   'o-dichlorobenzene',
#   'trans-1,2-dichloroethylene',
#   'trans-1,2-dichloroethylene',
#   '1,2,4-trichlorobenzene',
#   '1,2,4-trichlorobenzene',
#   'dibenz[a,h]anthracene',
#   'dibenz[a,h]anthracene',
#   'm-dichlorobenzene',
#   'm-dichlorobenzene',
#   '2-chloroethyl vinyl ether',
#   '2-chloroethyl vinyl ether',
#   '2-chloroethyl vinyl ether',
#   '2-chloroethyl vinyl ether',
#   '2-chloronaphthalene',
#   '2-chloronaphthalene',
#   'o-chlorophenol',
#   'o-chlorophenol',
#   'o-nitrophenol',
#   'o-nitrophenol',
#   'di-n-octyl phthalate',
#   'di-n-octyl phthalate',
#   '2,4-dinitrotoluene',
#   '2,4-dinitrotoluene',
#   '2,4-dinitrophenol',
#   '2,4-dinitrophenol',
#   '2,6-dinitrotoluene',
#   '2,6-dinitrotoluene',
#   "3,3'-dichlorobenzidine",
#   "3,3'-dichlorobenzidine",
#   'p-bromophenyl phenyl ether',
#   'p-bromophenyl phenyl ether',
#   'p-chlorophenyl phenyl ether',
#   'p-chlorophenyl phenyl ether',
#   'cfc-12',
#   '2,3,7,8-tetrachlorodibenzo-p-dioxin',
#   '2,3,7,8-tetrachlorodibenzo-p-dioxin',
#   'naphthalene',
#   'acrylamide',
#   'di(2-ethylhexyl) phthalate',
#   'di(2-ethylhexyl) phthalate',
#   'di(2-ethylhexyl) phthalate',
#   'di(2-ethylhexyl) phthalate',
#   'dibutyl phthalate',
#   'benzidine',
#   'vinyl chloride',
#   'trichloroethylene',
#   'hexachlorobutadiene',
#   'hcfc-22',
#   '2,6-dinitrotoluene',
#   '2,4-dinitrotoluene',
#   'nitrobenzene',
#   'cfc-11',
#   'cfc-12',
#   'aniline',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'methane',
#   '2-methylnaphthalene',
#   'cumene',
#   '2,3,7,8-tetrachlorodibenzo-p-dioxin',
#   '2,3,7,8-tetrachlorodibenzo-p-dioxin',
#   'benzoic acid',
#   'n-nitrosodimethylamine',
#   '1,2,4-trichlorobenzene',
#   'o-dichlorobenzene',
#   'm-dichlorobenzene',
#   '2,4-dinitrophenol',
#   '2,4-dinitrotoluene',
#   '2,6-dinitrotoluene',
#   '2-chloronaphthalene',
#   'o-chlorophenol',
#   'o-nitrophenol',
#   'p-bromophenyl phenyl ether',
#   'p-chlorophenyl phenyl ether',
#   'acenaphthene',
#   'acenaphthylene',
#   'anthracene',
#   'benz[a]anthracene',
#   'benzo[a]pyrene',
#   'benzo(b)fluoranthene',
#   'benzo[ghi]perylene',
#   'benzo[k]fluoranthene',
#   'bis(2-chloroethoxy)methane',
#   'bis(2-chloroethyl) ether',
#   'di(2-ethylhexyl) phthalate',
#   'di(2-ethylhexyl) phthalate',
#   'butyl benzyl phthalate',
#   'chrysene',
#   'dibenz[a,h]anthracene',
#   'diethyl phthalate',
#   'dimethyl phthalate',
#   'dibutyl phthalate',
#   'di-n-octyl phthalate',
#   'fluoranthene',
#   'fluorene',
#   'hexachlorobutadiene',
#   'hexachlorocyclopentadiene',
#   'hexachloroethane',
#   'indeno[1,2,3-cd]pyrene',
#   'isophorone',
#   'naphthalene',
#   'nitrobenzene',
#   'n-nitrosodi-n-propylamine',
#   'n-nitrosodiphenylamine',
#   'phenanthrene',
#   'pyrene',
#   'methane',
#   'methane',
#   'formaldehyde',
#   'ethyl methacrylate',
#   'methane',
#   'formaldehyde',
#   'acetaldehyde',
#   'ethanol',
#   'ethylene glycol',
#   'methyl acetate',
#   'isobutanol',
#   '1-butanol',
#   'vinyl acetate',
#   'aniline',
#   'cis-1,2-dichloroethylene',
#   '2-hexanone',
#   'styrene',
#   'p-xylene',
#   'm-xylene',
#   'o-xylene',
#   'benzyl alcohol',
#   '1,2,3-trimethylbenzene',
#   '1,2,4-trimethylbenzene',
#   'cumene',
#   'n-propylbenzene',
#   '1,3,5-trimethylbenzene',
#   'benzoic acid',
#   'o-chlorotoluene',
#   'n-butylbenzene',
#   'sec-butylbenzene',
#   'tert-butylbenzene',
#   'methanol',
#   'di(2-ethylhexyl) adipate',
#   'butane, 1-chloro-',
#   'methyl tert-butyl ether',
#   'p-xylene',
#   'methyl isobutyl ketone',
#   'methyl isobutyl ketone',
#   'm-nitroaniline',
#   'o-chlorotoluene',
#   'dibenzofuran',
#   'xylene',
#   'acetone',
#   'bromobenzene',
#   'nan',
#   'ethyl ether',
#   '1,4-dioxane',
#   'ethyl acetate',
#   'hexane',
#   'methyl ethyl ketone',
#   'methyl methacrylate',
#   'nan',
#   'm-xylene',
#   'o-xylene',
#   'methane',
#   'methane',
#   'methane',
#   'ethylene glycol',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'chloroform',
#   'dichlorobromomethane',
#   'chlorodibromomethane',
#   'tribromomethane',
#   'dichloroacetic acid',
#   'trichloroacetic acid',
#   'dichloroacetonitrile',
#   'dibromoacetonitrile',
#   'chloral hydrate'],
#  'organics, pcbs': ['polychlorinated biphenyls',
#   'polychlorinated biphenyls',
#   'polychlorinated biphenyls',
#   'polychlorinated biphenyls',
#   'polychlorinated biphenyls',
#   'polychlorinated biphenyls',
#   'polychlorinated biphenyls',
#   'polychlorinated biphenyls',
#   'polychlorinated biphenyls',
#   'aroclor 1262'],
#  'organics, pesticide': ['trifluralin',
#   'propachlor',
#   'butachlor',
#   'butylate',
#   'bromacil',
#   'simazine',
#   'prometryn',
#   'prometon',
#   '2-chloro-6-ethylamino-4-amino-s-triazine',
#   '2-chloro-4-isopropylamino-6-amino-s-triazine',
#   'cyanazine',
#   'dichlorprop',
#   'dinoseb',
#   'mcpa',
#   'mecoprop',
#   'dalapon',
#   'methyl bromide',
#   'ethylene dibromide',
#   '4,6-dinitro-o-cresol',
#   '4,6-dinitro-o-cresol',
#   'dichlorvos',
#   '2,4-db',
#   'bromacil',
#   'butachlor',
#   'butylate',
#   'propachlor',
#   'propoxur',
#   'p-chloroaniline',
#   '1,2-dichloroethane',
#   'acrylonitrile',
#   'acrylonitrile',
#   '.alpha.-hexachlorocyclohexane',
#   '.beta.-hexachlorocyclohexane',
#   'hexachlorobenzene',
#   'methyl bromide',
#   'methyl bromide',
#   'p-chloro-m-cresol',
#   'p-chloro-m-cresol',
#   '1,2-dichloroethane',
#   '1,2-dichloroethane',
#   '1,2-dichloropropane',
#   '1,2-dichloropropane',
#   '1,3-dichloropropene',
#   '1,3-dichloropropene',
#   'nan',
#   'nan',
#   'p-dichlorobenzene',
#   'p-dichlorobenzene',
#   '2,4-dichlorophenol',
#   '2,4-dichlorophenol',
#   '2,4-dimethylphenol',
#   '2,4-dimethylphenol',
#   '2,4,6-trichlorophenol',
#   '2,4,6-trichlorophenol',
#   'p-nitrophenol',
#   'p-nitrophenol',
#   "p,p'-ddd",
#   "p,p'-dde",
#   "p,p'-ddt",
#   '4,6-dinitro-o-cresol',
#   '4,6-dinitro-o-cresol',
#   '4,6-dinitro-o-cresol',
#   '4,6-dinitro-o-cresol',
#   'trans-1,3-dichloropropene',
#   'trans-1,3-dichloropropene',
#   'cis-1,3-dichloropropene',
#   'cis-1,3-dichloropropene',
#   'dicamba',
#   'mcpa',
#   'propazine',
#   'propoxur',
#   'trifluralin',
#   'bentazon',
#   'bentazon',
#   '2,4-db',
#   '1,2-dibromo-3-chloropropane',
#   'dichlorvos',
#   'oxamyl',
#   'oxamyl',
#   'endothall',
#   'chlorpyrifos',
#   'chlorpyrifos',
#   'chlorpyrifos',
#   'chlorpyrifos',
#   'dimethoate',
#   'phorate',
#   'propazine',
#   'simazine',
#   'trifluralin',
#   'methomyl',
#   'aldicarb',
#   'simazine',
#   'prometon',
#   'prometryn',
#   'cis-chlordane',
#   "p,p'-ddt",
#   "p,p'-ddd",
#   "p,p'-dde",
#   'aldrin',
#   'aldrin',
#   '.alpha.-hexachlorocyclohexane',
#   '.beta.-hexachlorocyclohexane',
#   'lindane',
#   'lindane',
#   'cis-chlordane',
#   'metolachlor',
#   "p,p'-ddd",
#   "p,p'-ddd",
#   "p,p'-dde",
#   "p,p'-dde",
#   "p,p'-ddt",
#   "p,p'-ddt",
#   'dieldrin',
#   'dieldrin',
#   'endrin',
#   'endrin',
#   'toxaphene',
#   'toxaphene',
#   'heptachlor',
#   'heptachlor',
#   'metolachlor',
#   'heptachlor epoxide',
#   'heptachlor epoxide',
#   'methoxychlor',
#   'malathion',
#   'malathion',
#   'parathion',
#   'parathion',
#   'diazinon',
#   'diazinon',
#   'azinphos-methyl',
#   'atrazine',
#   'atrazine',
#   'diuron',
#   'hexachlorobenzene',
#   '2,4-d',
#   '2,4-d',
#   '2,4,5-t',
#   '2,4,5-t',
#   'carbaryl',
#   'silvex',
#   'silvex',
#   'chlorthal-dimethyl',
#   'chlorthal-dimethyl',
#   'lindane',
#   '4,6-dinitro-o-cresol',
#   '4,6-dinitro-o-cresol',
#   'glyphosate',
#   'tebuthiuron',
#   'alachlor',
#   'alachlor',
#   'acetochlor',
#   'acetochlor',
#   'methomyl',
#   '4,6-dinitro-o-cresol',
#   '4,6-dinitro-o-cresol',
#   'diuron',
#   'dinoseb',
#   'dichlorprop',
#   '3-hydroxycarbofuran',
#   'carbofuran',
#   'carbaryl',
#   'bromoxynil',
#   'aldicarb',
#   'aldicarb sulfone',
#   'aldicarb sulfoxide',
#   'metolachlor',
#   'atrazine',
#   'metolachlor',
#   'metolachlor',
#   'atrazine',
#   'atrazine',
#   'p-chloroaniline',
#   'dalapon',
#   'mecoprop',
#   'methomyl',
#   'paraquat',
#   '2-chloro-6-ethylamino-4-amino-s-triazine',
#   '2,4,5-trichlorophenol',
#   'diuron',
#   'molinate',
#   'pendimethalin',
#   'pendimethalin',
#   '2,4-dichlorophenol',
#   'mecoprop',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'alachlor',
#   'alachlor',
#   'permethrin',
#   'p-cresol',
#   'cis-chlordane',
#   "p,p'-ddd",
#   "p,p'-dde",
#   "p,p'-ddt",
#   'diazinon',
#   'dichlorvos',
#   'glyphosate',
#   '.alpha.-hexachlorocyclohexane',
#   '.beta.-hexachlorocyclohexane',
#   'heptachlor epoxide',
#   'lindane',
#   'malathion',
#   'methoxychlor',
#   'parathion',
#   '2,4-db',
#   'p-dichlorobenzene',
#   '2,4,6-trichlorophenol',
#   '2,4-dichlorophenol',
#   '2-chloro-4-isopropylamino-6-amino-s-triazine',
#   '4,6-dinitro-o-cresol',
#   '4,6-dinitro-o-cresol',
#   'p-chloro-m-cresol',
#   'p-nitrophenol',
#   'acetochlor',
#   'alachlor',
#   'alachlor',
#   'aldrin',
#   '.alpha.-hexachlorocyclohexane',
#   'atrazine',
#   'azinphos-methyl',
#   'azobenzene',
#   '.beta.-hexachlorocyclohexane',
#   'butylate',
#   'carbaryl',
#   'carbofuran',
#   'chlorpyrifos',
#   'chlorpyrifos',
#   'cis-chlordane',
#   'cyanazine',
#   'chlorthal-dimethyl',
#   'diazinon',
#   'dieldrin',
#   'endrin',
#   's-ethyl dipropylthiocarbamate',
#   'heptachlor',
#   'heptachlor epoxide',
#   'hexachlorobenzene',
#   'lindane',
#   'malathion',
#   'metolachlor',
#   'metribuzin',
#   'molinate',
#   "p,p'-ddd",
#   "p,p'-dde",
#   "p,p'-ddt",
#   'methoxychlor',
#   'parathion',
#   'p-cresol',
#   'pendimethalin',
#   'pendimethalin',
#   'phorate',
#   'prometon',
#   'propachlor',
#   'simazine',
#   'tebuthiuron',
#   'terbufos',
#   'toxaphene',
#   'trifluralin',
#   'alachlor',
#   'alachlor',
#   'atrazine',
#   'azinphos-methyl',
#   'butylate',
#   'carbaryl',
#   'carbofuran',
#   'chlorpyrifos',
#   'chlorpyrifos',
#   'chlorthal-dimethyl',
#   'diazinon',
#   's-ethyl dipropylthiocarbamate',
#   'malathion',
#   'metolachlor',
#   'molinate',
#   "p,p'-ddd",
#   "p,p'-dde",
#   "p,p'-ddt",
#   'pendimethalin',
#   'pendimethalin',
#   'permethrin',
#   'prometryn',
#   'simazine',
#   'trifluralin',
#   'atrazine',
#   'metolachlor',
#   'simazine',
#   'diazinon',
#   'chlorpyrifos',
#   'chlorpyrifos',
#   '.alpha.-hexachlorocyclohexane',
#   'cis-chlordane',
#   'hexachlorobenzene',
#   'lindane',
#   "p,p'-ddd",
#   "p,p'-dde",
# ...
#   'bedload sediment, sieve diameter, percent smaller than 1 millimeter',
#   'bedload sediment, sieve diameter, percent smaller than 2 millimeters',
#   'bedload sediment, sieve diameter, percent smaller than 4 millimeters',
#   'bedload sediment, sieve diameter, percent smaller than 8 millimeters',
#   'bedload sediment, sieve diameter, percent smaller than 16 millimeters',
#   'bedload sediment, sieve diameter, percent smaller than 32 millimeters',
#   'bedload sediment, sieve diameter, percent smaller than 64 millimeters',
#   'bedload sediment, sieve diameter, percent smaller than 75 millimeters',
#   'bedload sediment, sieve diameter, percent smaller than 128 millimeters',
#   'bed sediment, sieve diameter, percent smaller than 0.355 millimeters',
#   'bed sediment, dry sieved, sieve diameter, percent smaller than 2.38 millimeters',
#   'bed sediment, fall diameter (deionized water), percent smaller than 0.016 millimeters',
#   'bed sediment, fall diameter (deionized water), percent smaller than 0.031 millimeters',
#   'bed sediment, fall diameter (deionized water), percent smaller than 0.088 millimeters',
#   'bed sediment, fall diameter (deionized water), percent smaller than 0.18 millimeters',
#   'bed sediment, fall diameter (deionized water), percent smaller than 0.35 millimeters',
#   'total sediment, fall diameter (deionized water), percent smaller than 0.088 millimeters',
#   'total sediment, fall diameter (deionized water), percent smaller than 0.18 millimeters',
#   'total sediment, fall diameter (deionized water), percent smaller than 0.35 millimeters',
#   'total sediment, fall diameter (native water), percent smaller than 0.088 millimeters',
#   'total sediment, fall diameter (native water), percent smaller than 0.177 millimeters',
#   'total sediment, fall diameter (native water), percent smaller than 0.35 millimeters',
#   'bed sediment, fall diameter (deionized water), percent smaller than 0.008 millimeters',
#   'bed sediment, fall diameter (deionized water), percent smaller than 0.002 millimeters',
#   'suspended sediment load, water, unfiltered, estimated by regression equation, pounds per second',
#   'suspended sediment load, water, unfiltered, estimated by regression equation, tons per second',
#   'suspended sediment load, water, unfiltered, computed, the product of regression-computed suspended sediment concentration and streamflow, tons per day',
#   'suspended sediment load, water, unfiltered, regression computed, turbidity and streamflow as regressors, tons per day',
#   'bedload sediment, total sample mass, dry weight, grams',
#   'suspended sediment concentration, water, unfiltered, estimated by regression equation, milligrams per liter'],
#  'stable isotopes': ['delta carbon-13 in organic fraction, soil or rock, per mil',
#   'sulfur-34/sulfur-32 ratio in sulfide, water, filtered, per mil',
#   'sulfur-34/sulfur-32 ratio in sulfide, bed sediment, per mil',
#   'thorium/uranium isotope ratio, water, unfiltered, number',
#   'sulfur-34/sulfur-32 ratio in sulfide, water, filtered, per mil',
#   'delta carbon-13 in carbon dioxide, per mil',
#   'delta carbon-13, rock, per mil',
#   'sulfur-34/sulfur-32 ratio in sulfate, rock, per mil',
#   'sulfur-34/sulfur-32 ratio in sulfide, rock, per mil',
#   'sulfur-34/sulfur-32 ratio in disulfide, rock, per mil',
#   'sulfur-34/sulfur-32 ratio in monosulfide, rock, per mil',
#   'sulfur-34/sulfur-32 ratio in sulfate, water, filtered, per mil',
#   'strontium-87 plus strontium-86, water, unfiltered, recoverable, micrograms per liter',
#   'delta helium-3, water, unfiltered, ingrowth method, percent',
#   'delta helium-3 error, water, unfiltered, ingrowth method, percent',
#   'helium-3/helium-4 ratio, water, unfiltered, ratio',
#   'boron-11/boron-10 ratio, water, filtered, per mil',
#   'delta nitrogen-15 in total nitrogen fraction, solids, per mil',
#   'delta nitrogen-15 in nitrate fraction, solids, per mil',
#   'delta nitrogen-15 in exchangeable ammonium fraction, solids, per mil',
#   'delta carbon-13 in total carbon fraction, solids, per mil',
#   'delta oxygen-18 in nitrate fraction, solids, per mil',
#   'delta oxygen-18 in nitrate fraction, water, filtered, per mil',
#   'delta nitrogen-15, dissolved gas, per mil',
#   'delta carbon-13 in organic carbon, biota, tissue, per mil',
#   'delta nitrogen-15 in organic nitrogen, biota, tissue, per mil',
#   'delta carbon-13 in organic carbon, suspended sediment, per mil',
#   'delta nitrogen-15 in organic nitrogen, suspended sediment, per mil',
#   'delta carbon-13 in organic carbon, bed sediment, per mil',
#   'delta nitrogen-15 in organic nitrogen, bed sediment, per mil',
#   'delta carbon-13 in organic carbon, water, filtered, per mil',
#   'delta carbon-13 in organic carbon 1-sigma uncertainty, water, filtered, per mil',
#   'delta carbon-13 in methane, water, dissolved, per mil relative to vienna peedee belemnite',
#   'delta carbon-13 in ethane, water, dissolved, headspace, per mil relative to vienna peedee belemnite',
#   'delta carbon-13 in inorganic carbon, water, dissolved, per mil relative to vienna peedee belemnite',
#   'delta deuterium in methane, water, dissolved, per mil relative to vienna standard mean ocean water',
#   'strontium-87/strontium-86 ratio, water, filtered, per mil',
#   'delta carbon-13, water, unfiltered, per mil',
#   'deuterium/protium ratio, water, unfiltered, per mil',
#   'lithium-7/lithium-6 ratio, water, unfiltered, per mil',
#   'delta nitrogen-15, water, unfiltered, per mil',
#   'delta oxygen-18, water, unfiltered, per mil',
#   'sulfur-34/sulfur-32 ratio, water, unfiltered, per mil',
#   'sulfur-34/sulfur-32 ratio, bed sediment, per mil',
#   'delta oxygen-18, bed sediment, per mil',
#   'delta nitrogen-15, bed sediment, per mil',
#   'delta carbon-13, bed sediment, per mil',
#   'delta nitrogen-15 in organic nitrogen, soil or rock, per mil',
#   'delta nitrogen-15 in nitrate fraction, soil, per mil',
#   'delta nitrogen-15 in ammonia fraction, soil, per mil',
#   'delta nitrogen-15 in nitrate fraction, water, filtered, per mil',
#   'delta nitrogen-15 in ammonia fraction, water, filtered, per mil',
#   'delta nitrogen-15 in nitrogen gas fraction, water, unfiltered, per mil',
#   'delta oxygen-18 in dissolved oxygen, water, unfiltered, per mil',
#   'delta carbon-13 in carbonate fraction, solids, per mil',
#   'chromium-53/chromium-52 isotope ratio, water, filtered, per mil',
#   'boron-11/boron-10 ratio, water, unfiltered, per mil',
#   'chlorine-37/chlorine-35 ratio, water, filtered, per mil',
#   'bromine-81/bromine-79 ratio, water, filtered, per mil',
#   'delta oxygen-18 in sulfate, water, filtered, per mil',
#   'delta carbon-13, organic solid materials, per mil',
#   'carbon-14, organic solid materials, percent modern',
#   'chlorine-37/chlorine-35 ratio in perchlorate, water, unfiltered, per mil',
#   'delta oxygen-18 in perchlorate, water, unfiltered, per mil',
#   'oxygen-17/oxygen-16 ratio in perchlorate, water, unfiltered, ratio',
#   'strontium-87/strontium-86 ratio, carbonate rock, 3n nitric acid extracted, per mil',
#   'delta oxygen-18, carbonate rock, relative to vienna standard mean ocean water (vsmow), per mil',
#   'delta carbon-13 in propane, water, filtered, headspace, per mil relative to vienna peedee belemnite',
#   'carbon-13 in methane, water, unfiltered, percent',
#   'deuterium in methane, water, unfiltered, percent',
#   'oxygen-18 in water molecules, water, unfiltered, percent',
#   'strontium-87/strontium-86 ratio, water, filtered, normalized to standard reference material, ratio',
#   'delta strontium-87, water, filtered, as standard deviation from seawater, per mil',
#   'delta sulfur-34, water, filtered, per mil relative to vienna canyon diablo troilite (vcdt) standard',
#   'helium-4, water, unfiltered, cubic centimeters per gram at standard temperature and pressure',
#   'helium-4 error, water, unfiltered, cubic centimeters per gram at standard temperature and pressure',
#   'helium-3/helium-4 error, water, unfiltered, ratio',
#   'neon-20, water, unfiltered, cubic centimeters per gram at standard temperature and pressure',
#   'neon-20 error, water, unfiltered, cubic centimeters per gram at standard temperature and pressure',
#   'neon-22, water, unfiltered, cubic centimeters per gram at standard temperature and pressure',
#   'neon-22 error, water, unfiltered, cubic centimeters per gram at standard temperature and pressure'],
#  'toxicity': ['mean survival of fathead minnows (pimephales promelas) on day 7 of 7-day exposure to 100 percent effluent water sample, percent',
#   'biomass of fathead minnows (pimephales promelas) on day 7 of 7-day exposure to 100 percent effluent water sample, milligrams',
#   'mercury, waste/reagent water mixture, unfiltered, epa toxicity test (sw-1310), micrograms per liter',
#   'barium, waste/reagent water mixture, unfiltered, epa toxicity test (sw-1310), micrograms per liter',
#   'cadmium, waste/reagent water mixture, unfiltered, epa toxicity test (sw-1310), micrograms per liter',
#   'chromium, waste/reagent water mixture, unfiltered, epa toxicity test (sw-1310), micrograms per liter',
#   'lead, waste/reagent water mixture, unfiltered, epa toxicity test (sw-1310), micrograms per liter',
#   'selenium, waste/reagent water mixture, unfiltered, epa toxicity test (sw-1310), micrograms per liter',
#   'silver, waste/reagent water mixture, unfiltered, epa toxicity test (sw-1310), micrograms per liter',
#   'arsenic, waste/reagent water mixture, unfiltered, epa toxicity test (sw-1310), micrograms per liter',
#   'silver, waste/reagent water mixture leachate, epa toxicity characteristic leaching procedure (1311), micrograms per liter',
#   'mercury, waste/reagent water mixture leachate, epa toxicity characteristic leaching procedure (1311), micrograms per liter',
#   '1,4-dichlorobenzene, waste/reagent water mixture leachate, epa toxicity characteristic leaching procedure (1311), milligrams per liter',
#   'benzene, waste/reagent water mixture leachate, epa toxicity characteristic leaching procedure (1311), milligrams per liter',
#   'methyl ethyl ketone, waste/reagent water mixture leachate, epa toxicity characteristic leaching procedure (1311), milligrams per liter',
#   'tetrachloromethane, waste/reagent water mixture leachate, epa toxicity characteristic leaching procedure (1311), milligrams per liter',
#   'chlorobenzene, waste/reagent water mixture leachate, epa toxicity characteristic leaching procedure (1311), milligrams per liter',
#   'trichloromethane, waste/reagent water mixture leachate, epa toxicity characteristic leaching procedure (1311), milligrams per liter',
#   '1,2-dichloroethane, waste/reagent water mixture leachate, epa toxicity characteristic leaching procedure (1311), milligrams per liter',
#   '1,1-dichloroethene, waste/reagent water mixture leachate, epa toxicity characteristic leaching procedure (1311), milligrams per liter',
#   'tetrachloroethene, waste/reagent water mixture leachate, epa toxicity characteristic leaching procedure (1311), milligrams per liter',
#   'trichloroethene, waste/reagent water mixture leachate, epa toxicity characteristic leaching procedure (1311), milligrams per liter',
#   'vinyl chloride, waste/reagent water mixture leachate, epa toxicity characteristic leaching procedure (1311), milligrams per liter',
#   'arsenic, waste/reagent water mixture leachate, epa toxicity characteristic leaching procedure (1311), micrograms per liter',
#   'barium, waste/reagent water mixture leachate, epa toxicity characteristic leaching procedure (1311), micrograms per liter',
#   'cadmium, waste/reagent water mixture leachate, epa toxicity characteristic leaching procedure (1311), micrograms per liter',
#   'chromium, waste/reagent water mixture leachate, epa toxicity characteristic leaching procedure (1311), micrograms per liter',
#   'lead, waste/reagent water mixture leachate, epa toxicity characteristic leaching procedure (1311), micrograms per liter',
#   'selenium, waste/reagent water mixture leachate, epa toxicity characteristic leaching procedure (1311), micrograms per liter',
#   'ph, 100 percent effluent water sample on day 0 of 7-day exposure, unfiltered, standard units',
#   'ph, 100 percent effluent water sample on day 2 of 7-day exposure, unfiltered, standard units',
#   'ph, 100 percent effluent water sample on day 7 of 7-day exposure, unfiltered, standard units',
#   'dissolved oxygen (do), 100 percent effluent water sample on day 0 of 7-day exposure, unfiltered, milligrams per liter',
#   'dissolved oxygen (do), 100 percent effluent water sample on day 2 of 7-day exposure, unfiltered, milligrams per liter',
#   'dissolved oxygen (do), 100 percent effluent water sample on day 7 of 7-day exposure, unfiltered, milligrams per liter',
#   'specific conductance (sc), 100 percent effluent water sample on day 0 of 7-day exposure, unfiltered, microsiemens per centimeter at 25 degrees celsius',
#   'specific conductance (sc), 100 percent effluent water sample on day 2 of 7-day exposure, unfiltered, microsiemens per centimeter at 25 degrees celsius',
#   'specific conductance (sc), 100 percent effluent water sample on day 7 of 7-day exposure, unfiltered, microsiemens per centimeter at 25 degrees celsius',
#   'hardness, 100 percent effluent water sample on day 0 of 7-day exposure, unfiltered, milligrams per liter as calcium carbonate',
#   'hardness, 100 percent effluent water sample on day 2 of 7-day exposure, unfiltered, milligrams per liter as calcium carbonate',
#   'hardness, 100 percent effluent water sample on day 7 of 7-day exposure, unfiltered, milligrams per liter as calcium carbonate',
#   'acid neutralizing capacity (anc), 100 percent effluent water sample on day 0 of 7-day exposure, unfiltered, milligrams per liter as calcium carbonate',
#   'acid neutralizing capacity (anc), 100 percent effluent water sample on day 2 of 7-day exposure, unfiltered, milligrams per liter as calcium carbonate',
#   'acid neutralizing capacity (anc), 100 percent effluent water sample on day 7 of 7-day exposure, unfiltered, milligrams per liter as calcium carbonate',
#   'ammonia, 100 percent effluent water sample on day 0 of 7-day exposure, unfiltered, milligrams per liter as nitrogen',
#   'ammonia, 100 percent effluent water sample on day 2 of 7-day exposure, unfiltered, milligrams per liter as nitrogen',
#   'ammonia, 100 percent effluent water sample on day 7 of 7-day exposure, unfiltered, milligrams per liter as nitrogen',
#   'ammonia (un-ionized), 100 percent effluent water sample on day 0 of 7-day exposure, unfiltered, milligrams per liter as nitrogen',
#   'ammonia (un-ionized), 100 percent effluent water sample on day 2 of 7-day exposure, unfiltered, milligrams per liter as nitrogen',
#   'ammonia (un-ionized), 100 percent effluent water sample on day 7 of 7-day exposure, unfiltered, milligrams per liter as nitrogen',
#   'calcium, 100 percent effluent water sample on day 0 of 7-day exposure, filtered, milligrams per liter',
#   'calcium, 100 percent effluent water sample on day 2 of 7-day exposure, filtered, milligrams per liter',
#   'potassium, 100 percent effluent water sample on day 0 of 7-day exposure, filtered, milligrams per liter',
#   'potassium, 100 percent effluent water sample on day 2 of 7-day exposure, filtered, milligrams per liter',
#   'magnesium, 100 percent effluent water sample on day 0 of 7-day exposure, filtered, milligrams per liter',
#   'magnesium, 100 percent effluent water sample on day 2 of 7-day exposure, filtered, milligrams per liter',
#   'sodium, 100 percent effluent water sample on day 0 of 7-day exposure, filtered, milligrams per liter',
#   'sodium, 100 percent effluent water sample on day 2 of 7-day exposure, filtered, milligrams per liter',
#   'sulfate, 100 percent effluent water sample on day 0 of 7-day exposure, filtered, milligrams per liter',
#   'sulfate, 100 percent effluent water sample on day 2 of 7-day exposure, filtered, milligrams per liter',
#   'chloride, 100 percent effluent water sample on day 0 of 7-day exposure, filtered, milligrams per liter',
#   'chloride, 100 percent effluent water sample on day 2 of 7-day exposure, filtered, milligrams per liter']}

# %%
biological, information, inorganics_major_metals, inorganics_major_nonmetals = [],[],[],[]
inorganics_minor_metals, inorganics_minor_nonmetals, microbiological, nutrient, = [],[],[],[]
organics_other, organics_PCBs, organics_pesticide, physical, population_community = [],[],[],[],[]
radiochemical, sediment, stable_isotopes, toxicity = [],[],[],[]

groups = [biological, information, inorganics_major_metals, inorganics_major_nonmetals, inorganics_minor_metals,
inorganics_minor_nonmetals, microbiological,
nutrient, organics_other, organics_PCBs, organics_pesticide, physical, population_community, radiochemical, 
sediment, stable_isotopes, toxicity]

# %%
for i in range(len(parlist)):
    groups[i] = (z[parlist[i]])

# %%
def flattenList(listToFlatten):
    a = listToFlatten
    b= [i[x] for i in a for x in range(len(i))]
    return (sorted(list(set(b))))

# %%
flattened = []
for i in groups:
    i = (flattenList(i))

# %%
inorganics_major_metals
# Out:
# []

# %%
print(parList1[1])
print(parList2[1])
# Out:
# ['information', 'inorganics, major, metals', 'inorganics, major, non-metals', 'nutrient', 'inorganics, minor, metals', 'inorganics, minor, non-metals', 'organics, pesticide', 'organics, pcbs', 'organics, other', 'radiochemical']
# ['information', 'physical', 'radiochemical', 'inorganics, major, non-metals', 'sediment', 'organics, other', 'biological', 'nutrient', 'inorganics, minor, non-metals', 'inorganics, major, metals', 'inorganics, minor, metals', 'stable isotopes', 'organics, pesticide', 'organics, pcbs', 'microbiological', 'toxicity', 'population/community']

# %%
SDWISmatch
# Out:
#                                                KEY   ID CAS_Registry_Number  \
# 0                                          2,4-DB    29             94-82-6
# 1                                          2,4-DB    29             94-82-6
# 2                                          2,4-DB    29             94-82-6
# 3                                         Atrazine   63           1912-24-9
# 4                                         Bromacil  476            314-40-9
# 5                                        Cyanazine  135          21725-46-2
# 6     2-chloro-4-amino-6-isopropylamino-s-triazine  535           6190-65-4
# 7                                           Diuron  167            330-54-1
# 8                                         Prometon  447           1610-18-0
# 9                                        Propazine  433            139-40-2
# 10                                        Simazine  304            122-34-9
# 11                                      Acetochlor  482          34256-82-1
# 12                                        Alachlor   54          15972-60-8
# 13                                        Alachlor   54          15972-60-8
# 14                                     Metolachlor  241          51218-45-2
# 15                             Propachlor (Ramrod)  455           1918-16-7
# 16                          1,2,3-Trichloropropane    8             96-18-4
# 17                          1,1,2-Trichloropropane    4             96-18-4
# 18                          N-Nitrosodimethylamine  581             62-75-9
# 19                                     1,4-Dioxane  424            123-91-1
# 20             2,4,5-Trichlorophenoxy acetic acid    26             93-76-5
# 21                                              Ca  107           7440-70-2
# 22                                              Ca  107           7440-70-2
# 23                                              Ca  107           7440-70-2
# 24                                              Ca  107           7440-70-2
# 25                                              Ca  107           7440-70-2
# 26                                              Ca  107           7440-70-2
# 27                                              Ca  107           7440-70-2
# 28                                              Ca  107           7440-70-2
# 29                                              Mg  220           7439-95-4
# ...                                            ...  ...                 ...
# 2002                                   Gross Alpha  425          12587-46-1
# 2003                                   Gross Alpha  425          12587-46-1
# 2004                                   Gross Alpha  425          12587-46-1
# 2005                                   Gross Alpha  425          12587-46-1
# 2006                                   Gross Alpha  425          12587-46-1
# 2007                                   Gross Alpha  425          12587-46-1
# 2008                                    Gross Beta  426          12587-47-2
# 2009                                    Gross Beta  426          12587-47-2
# 2010                                    Gross Beta  426          12587-47-2
# 2011                                    Gross Beta  426          12587-47-2
# 2012                                    Gross Beta  426          12587-47-2
# 2013                                    Gross Beta  426          12587-47-2
# 2014                                    Radium 228  443          15262-20-1
# 2015                                    Radium 228  443          15262-20-1
# 2016                                    Gross Beta  426          12587-47-2
# 2017                                    Gross Beta  426          12587-47-2
# 2018                                    Gross Beta  426          12587-47-2
# 2019                                             U  336           7440-61-1
# 2020                                             U  336           7440-61-1
# 2021                                             U  336           7440-61-1
# 2022                                             U  336           7440-61-1
# 2023                                    Gross Beta  426          12587-47-2
# 2024                                    Gross Beta  426          12587-47-2
# 2025                                    Gross Beta  426          12587-47-2
# 2026                                    Radium 226  434          13982-63-3
# 2027                                    Radium 228  443          15262-20-1
# 2028                                   Gross Alpha  425          12587-46-1
# 2029                                   Gross Alpha  425          12587-46-1
# 2030                                   Gross Alpha  425          12587-46-1
# 2031                                   Gross Alpha  425          12587-46-1
#
#       parameter_cd_txt         parameter_group_nm  \
# 0                90591                Information
# 1                90592                Information
# 2                90593                Information
# 3                91622                Information
# 4                91623                Information
# 5                91624                Information
# 6                91627                Information
# 7                91635                Information
# 8                91641                Information
# 9                91642                Information
# 10               91643                Information
# 11               91644                Information
# 12               91652                Information
# 13               91652                Information
# 14               91668                Information
# 15               91673                Information
# 16               91824                Information
# 17               91824                Information
# 18               91825                Information
# 19               91826                Information
# 20               99958                Information
# 21                 910  Inorganics, Major, Metals
# 22                 910  Inorganics, Major, Metals
# 23                 915  Inorganics, Major, Metals
# 24                 915  Inorganics, Major, Metals
# 25                 916  Inorganics, Major, Metals
# 26                 916  Inorganics, Major, Metals
# 27                 918  Inorganics, Major, Metals
# 28                 918  Inorganics, Major, Metals
# 29                 920  Inorganics, Major, Metals
# ...                ...                        ...
# 2002             80029              Radiochemical
# 2003             80029              Radiochemical
# 2004             80030              Radiochemical
# 2005             80030              Radiochemical
# 2006             80030              Radiochemical
# 2007             80030              Radiochemical
# 2008             80049              Radiochemical
# 2009             80049              Radiochemical
# 2010             80049              Radiochemical
# 2011             80050              Radiochemical
# 2012             80050              Radiochemical
# 2013             80050              Radiochemical
# 2014             81366              Radiochemical
# 2015             81367              Radiochemical
# 2016             85817              Radiochemical
# 2017             85817              Radiochemical
# 2018             85817              Radiochemical
# 2019             91703              Radiochemical
# 2020             91703              Radiochemical
# 2021             91725              Radiochemical
# 2022             91725              Radiochemical
# 2023             99323              Radiochemical
# 2024             99323              Radiochemical
# 2025             99323              Radiochemical
# 2026             99325              Radiochemical
# 2027             99326              Radiochemical
# 2028             99337              Radiochemical
# 2029             99337              Radiochemical
# 2030             99337              Radiochemical
# 2031             99337              Radiochemical
#
#                                                 srsname  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                              Calcium
# 22                                              Calcium
# 23                                              Calcium
# 24                                              Calcium
# 25                                              Calcium
# 26                                              Calcium
# 27                                              Calcium
# 28                                              Calcium
# 29                                            Magnesium
# ...                                                 ...
# 2002                                     Alpha particle
# 2003                                     Alpha particle
# 2004                                     Alpha particle
# 2005                                     Alpha particle
# 2006                                     Alpha particle
# 2007                                     Alpha particle
# 2008                                      Beta particle
# 2009                                      Beta particle
# 2010                                      Beta particle
# 2011                                      Beta particle
# 2012                                      Beta particle
# 2013                                      Beta particle
# 2014                                         Radium-228
# 2015                                         Radium-228
# 2016                                      Beta particle
# 2017                                      Beta particle
# 2018                                      Beta particle
# 2019  Uranium-234 and/or uranium-235 and/or uranium-238
# 2020  Uranium-234 and/or uranium-235 and/or uranium-238
# 2021  Uranium-234 and/or uranium-235 and/or uranium-238
# 2022  Uranium-234 and/or uranium-235 and/or uranium-238
# 2023                                      Beta particle
# 2024                                      Beta particle
# 2025                                      Beta particle
# 2026                                         Radium-226
# 2027                                         Radium-228
# 2028                                     Alpha particle
# 2029                                     Alpha particle
# 2030                                     Alpha particle
# 2031                                     Alpha particle
#
#                                            parameter_nm  TSAANLYT_IS_NUMBER  \
# 0     2,4-DB, surrogate, NWQL Schedule 79, water, un...                 744
# 1     2,4-DB, surrogate, NWQL Schedule 1301, water, ...                 744
# 2     2,4-DB, surrogate, NWQL Schedule 1304, water, ...                 744
# 3     Atrazine, spike, water, filtered, apparent per...                 129
# 4     Bromacil, spike, water, filtered, percent reco...                 742
# 5     Cyanazine, spike, water, filtered, percent rec...                 133
# 6     2-Chloro-4-isopropylamino-6-amino-s-triazine, ...                 734
# 7      Diuron, spike, water, filtered, percent recovery                 838
# 8     Prometon, spike, water, filtered, percent reco...                 740
# 9     Propazine, spike, water, filtered, percent rec...                 758
# 10    Simazine, spike, water, filtered, percent reco...                 116
# 11    Acetochlor, spike, water, filtered, percent re...                 738
# 12    Alachlor, spike, water, filtered, percent reco...                 832
# 13    Alachlor, spike, water, filtered, percent reco...                 130
# 14    Metolachlor, spike, water, filtered, percent r...                 124
# 15    Propachlor, spike, water, filtered, percent re...                 156
# 16    1,2,3-Trichloropropane, spike, water, unfilter...                 306
# 17    1,2,3-Trichloropropane, spike, water, unfilter...                 306
# 18    N-Nitrosodimethylamine, spike, water, unfilter...                 254
# 19    1,4-Dioxane, spike, water, unfiltered, percent...                 128
# 20    2,4,5-T, surrogate, Schedule 9060/2060, water,...                 178
# 21    Calcium, water, unfiltered, milligrams per lit...                 733
# 22    Calcium, water, unfiltered, milligrams per lit...                  13
# 23       Calcium, water, filtered, milligrams per liter                 733
# 24       Calcium, water, filtered, milligrams per liter                  13
# 25    Calcium, water, unfiltered, recoverable, milli...                 733
# 26    Calcium, water, unfiltered, recoverable, milli...                  13
# 27    Calcium, water, unfiltered, recoverable, milli...                 733
# 28    Calcium, water, unfiltered, recoverable, milli...                  13
# 29    Magnesium, water, unfiltered, milligrams per l...                  26
# ...                                                 ...                 ...
# 2002  Gross alpha radioactivity, water, unfiltered, ...                 422
# 2003  Gross alpha radioactivity, water, unfiltered, ...                 421
# 2004  Gross alpha radioactivity, water, filtered, na...                 411
# 2005  Gross alpha radioactivity, water, filtered, na...                 432
# 2006  Gross alpha radioactivity, water, filtered, na...                 422
# 2007  Gross alpha radioactivity, water, filtered, na...                 421
# 2008  Gross beta radioactivity, water, unfiltered, S...                 423
# 2009  Gross beta radioactivity, water, unfiltered, S...                 426
# 2010  Gross beta radioactivity, water, unfiltered, S...                 424
# 2011  Gross beta radioactivity, water, filtered, Sr-...                 423
# 2012  Gross beta radioactivity, water, filtered, Sr-...                 426
# 2013  Gross beta radioactivity, water, filtered, Sr-...                 424
# 2014  Radium-228, water, filtered, picocuries per liter                 420
# 2015  Radium-228 counting error, water, filtered, pi...                 420
# 2016  Gross beta radioactivity, water, unfiltered, p...                 423
# 2017  Gross beta radioactivity, water, unfiltered, p...                 426
# 2018  Gross beta radioactivity, water, unfiltered, p...                 424
# 2019  Uranium, solids, 10% nitric acid extracted, re...                 413
# 2020  Uranium, solids, 10% nitric acid extracted, re...                 416
# 2021  Uranium, solids, 6 N hydrochloric acid extract...                 413
# 2022  Uranium, solids, 6 N hydrochloric acid extract...                 416
# 2023  Gross beta radioactivity sample-specific minim...                 423
# 2024  Gross beta radioactivity sample-specific minim...                 426
# 2025  Gross beta radioactivity sample-specific minim...                 424
# 2026  Radium-226 sample-specific minimum detectable ...                 419
# 2027  Radium-228 sample-specific minimum detectable ...                 420
# 2028  Gross alpha radioactivity 2X critical level (s...                 411
# 2029  Gross alpha radioactivity 2X critical level (s...                 432
# 2030  Gross alpha radioactivity 2X critical level (s...                 422
# 2031  Gross alpha radioactivity 2X critical level (s...                 421
#
#                                     SDWIS_NAME
# 0     2,4-DB
# 1     2,4-DB
# 2     2,4-DB
# 3     ATRAZINE
# 4     BROMACIL
# 5                                    CYANAZINE
# 6                             DESETHYLATRAZINE
# 7     DIURON
# 8                                     PROMETON
# 9     PROPAZINE
# 10    SIMAZINE
# 11    ACETOCHLOR
# 12    ALACHLOR ESA
# 13                                       LASSO
# 14    METOLACHLOR
# 15    PROPACHLOR
# 16    1,2,3-TRICHLOROPROPANE
# 17    1,2,3-TRICHLOROPROPANE
# 18    N-NITROSODIMETHYLAMINE
# 19    1,4-DIOXANE
# 20    2,4,5-T
# 21    CALCIUM
# 22    CALCIUM
# 23    CALCIUM
# 24    CALCIUM
# 25    CALCIUM
# 26    CALCIUM
# 27    CALCIUM
# 28    CALCIUM
# 29    MAGNESIUM
# ...                                        ...
# 2002                          ALPHA, SUSPENDED
# 2003                          ALPHA, DISSOLVED
# 2004  GROSS ALPHA, INCL. RADON & U
# 2005             GROSS ALPHA PARTICLE ACTIVITY
# 2006                          ALPHA, SUSPENDED
# 2007                          ALPHA, DISSOLVED
# 2008                           BETA, DISSOLVED
# 2009  GROSS BETA PARTICLE ACTIVITY
# 2010                           BETA, SUSPENDED
# 2011                           BETA, DISSOLVED
# 2012  GROSS BETA PARTICLE ACTIVITY
# 2013                           BETA, SUSPENDED
# 2014  RADIUM-228
# 2015  RADIUM-228
# 2016                           BETA, DISSOLVED
# 2017  GROSS BETA PARTICLE ACTIVITY
# 2018                           BETA, SUSPENDED
# 2019                          COMBINED URANIUM
# 2020  URANIUM-238
# 2021                          COMBINED URANIUM
# 2022  URANIUM-238
# 2023                           BETA, DISSOLVED
# 2024  GROSS BETA PARTICLE ACTIVITY
# 2025                           BETA, SUSPENDED
# 2026  RADIUM-226
# 2027  RADIUM-228
# 2028  GROSS ALPHA, INCL. RADON & U
# 2029             GROSS ALPHA PARTICLE ACTIVITY
# 2030                          ALPHA, SUSPENDED
# 2031                          ALPHA, DISSOLVED
#
# [2032 rows x 9 columns]
